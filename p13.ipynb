# %% [markdown]
# <img src="https://i.imgur.com/FoKB5Z5.png" align="left" width="300" height="250" title="source: imgur.com" /></a>

# %% [markdown]
# ## Program Code: J620-002-4:2020
#
# ## Program Name: FRONT-END SOFTWARE DEVELOPMENT
#
# ## Title :   Introduction of BeautifulSoup - Part 1
#
# #### Name:
#
# #### IC Number:
#
# #### Date :
#
# #### Introduction :
#
#
#
# #### Conclusion :

# %% [markdown]
# # P13 -  Introduction of BeautifulSoup - Part 1

# %% [markdown]
# ### HTML and CSS
#
# Let's start explore how a Web page HTML doc works with CSS (Cascading Style Sheet)
#
# https://codepen.io/buzztracer/pen/yLYJBOd

# %% [markdown]
# ### HTML div Tag
#
#
# **Definition and Usage**
#
# The div tag defines a division or a section in an HTML document.
#
# The div element is often used as a container for other HTML elements to style them with CSS or to perform certain tasks with JavaScript.
#
#
# <tag id=""></tag>

# %% [markdown]
# ### HTML  Id Attributes
#
# **Definition and Usage**
#
# The id attribute is a unique identifier which is used to specify the document.
#
# It is used by CSS and JavaScript to perform a certain task for a unique element.
#
# In CSS, the id attribute is used using # symbol followed by id.

# %% [markdown]
# ### HTML Class Attribute
#
# **Definition and Usage**
#
# Class in html:
#
# The class is an attribute which specifies one or more class names for an HTML element.
#
# The class attribute can be used on any HTML element.
#
# The class name can be used by CSS and JavaScript to perform certain tasks for elements with the specified class name.

# %% [markdown]
# ### How a web page call another?
#
# By using the < a >: Anchor element
#
# https://developer.mozilla.org/en-US/docs/Web/HTML/Element/a

# %%
# Get all hyperlinks

import requests

from bs4 import BeautifulSoup

html = requests.get('http://en.wikipedia.org/wiki/Malaysia')
bs = BeautifulSoup(html.content, 'html.parser')

print(bs)

for link in bs.find_all('a'):
    if 'href' in link.attrs:
        print(link.attrs['href'])
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-enabled vector-feature-main-menu-pinned-disabled vector-feature-limited-width-enabled vector-feature-limited-width-content-enabled vector-feature-zebra-design-disabled" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Malaysia - Wikipedia</title>
# <script>document.documentElement.className="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-enabled vector-feature-main-menu-pinned-disabled vector-feature-limited-width-enabled vector-feature-limited-width-content-enabled vector-feature-zebra-design-disabled";(function(){var cookie=document.cookie.match(/(?:^|; )enwikimwclientprefs=([^;]+)/);if(cookie){var featureName=cookie[1];document.documentElement.className=document.documentElement.className.replace(featureName+'-enabled',featureName+'-disabled');}}());RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"d0af4588-d2c6-4a06-972b-5b270f4742cf","wgCSPNonce":false,
# "wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Malaysia","wgTitle":"Malaysia","wgCurRevisionId":1159764273,"wgRevisionId":1159764273,"wgArticleId":3607937,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Articles containing Malay (macrolanguage)-language text","All articles lacking reliable references","Articles lacking reliable references from June 2022","Harv and Sfn no-target errors","Wikipedia articles incorporating a citation from the 1911 Encyclopaedia Britannica with Wikisource reference","CS1 errors: missing periodical","All articles with dead external links","Articles with dead external links from February 2023","Articles with permanently dead external links","CS1 maint: unfit URL","CS1 Malay-language sources (ms)","CS1 Indonesian-language sources (id)","Articles with short description","Short description matches Wikidata",
# "Wikipedia pages semi-protected against vandalism","Wikipedia indefinitely semi-protected pages","Good articles","Use British English from August 2019","Use dmy dates from June 2023","Pages using infobox country or infobox former country with the symbol caption or type parameters","Articles with hAudio microformats","Pages including recorded pronunciations","Articles containing Sanskrit-language text","Articles containing Tamil-language text","Articles containing Portuguese-language text","Pages using multiple image with auto scaled images","All articles with unsourced statements","Articles with unsourced statements from January 2023","Articles with unsourced statements from October 2022","Articles containing potentially dated statements from 2016","All articles containing potentially dated statements","Pages using largest cities with class","All articles that are too technical","Wikipedia articles that are too technical from October 2022","All articles needing expert attention",
# "Articles needing expert attention from October 2022","Articles containing potentially dated statements from June 2022","Pages using Sister project links with hidden wikidata","Pages using Sister project links with default search","Articles with Curlie links","Articles with FAST identifiers","Articles with ISNI identifiers","Articles with VIAF identifiers","Articles with BIBSYS identifiers","Articles with BNE identifiers","Articles with BNF identifiers","Articles with BNFdata identifiers","Articles with CANTICN identifiers","Articles with GND identifiers","Articles with J9U identifiers","Articles with LCCN identifiers","Articles with Libris identifiers","Articles with NDL identifiers","Articles with NKC identifiers","Articles with NLA identifiers","Articles with NLK identifiers","Articles with MusicBrainz area identifiers","Articles with CINII identifiers","Articles with Trove identifiers","Articles with EMU identifiers","Articles with HDS identifiers","Articles with NARA identifiers",
# "Articles with SUDOC identifiers","Articles with TDVİA identifiers","Coordinates on Wikidata","Malaysia","Countries in Asia","Member states of ASEAN","Malay-speaking countries and territories","Member states of the Organisation of Islamic Cooperation","Member states of the United Nations","Commonwealth monarchies","Developing 8 Countries member states","Federal monarchies","Member states of the Commonwealth of Nations","G15 nations","Southeast Asian countries","States and territories established in 1963","World War II sites","1963 establishments in Malaysia"],"wgPageViewLanguage":"en","wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgRelevantPageName":"Malaysia","wgRelevantArticleId":3607937,"wgIsProbablyEditable":false,"wgRelevantPageIsProbablyEditable":false,"wgRestrictionEdit":["autoconfirmed"],"wgRestrictionMove":["sysop"],"wgFlaggedRevsParams":{"tags":{"status":{"levels":1}}},"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":
# "en"},"wgMFDisplayWikibaseDescriptions":{"search":true,"watchlist":true,"tagline":false,"nearby":true},"wgWMESchemaEditAttemptStepOversample":false,"wgWMEPageLength":200000,"wgNoticeProject":"wikipedia","wgMediaViewerOnClick":true,"wgMediaViewerEnabledByDefault":true,"wgPopupsFlags":10,"wgULSCurrentAutonym":"English","wgCoordinates":{"lat":2,"lon":112},"wgEditSubmitButtonLabelPublish":true,"wgCentralAuthMobileDomain":false,"wgULSPosition":"interlanguage","wgULSisCompactLinksEnabled":true,"wgULSisLanguageSelectorEmpty":false,"wgWikibaseItemId":"Q833","GEHomepageSuggestedEditsEnableTopics":true,"wgGETopicsMatchModeEnabled":false,"wgGEStructuredTaskRejectionReasonTextInputEnabled":false,"wgGELevelingUpEnabledForUser":false};RLSTATE={"skins.vector.user.styles":"ready","ext.globalCssJs.user.styles":"ready","site.styles":"ready","user.styles":"ready","skins.vector.user":"ready","ext.globalCssJs.user":"ready","user":"ready","user.options":"loading","ext.cite.styles":"ready",
# "ext.tmh.player.styles":"ready","codex-search-styles":"ready","skins.vector.styles":"ready","skins.vector.icons":"ready","jquery.makeCollapsible.styles":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.wikimediaBadges":"ready","ext.uls.interlanguage":"ready","wikibase.client.init":"ready"};RLPAGEMODULES=["ext.cite.ux-enhancements","ext.tmh.player","ext.scribunto.logs","site","mediawiki.page.ready","jquery.makeCollapsible","mediawiki.toc","skins.vector.js","mmv.head","mmv.bootstrap.autostart","ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.eventLogging","ext.wikimediaEvents","ext.navigationTiming","ext.cx.eventlogging.campaigns","ext.quicksurveys.init","ext.centralNotice.geoIP","ext.centralNotice.startUp","ext.gadget.ReferenceTooltips","ext.gadget.charinsert","ext.gadget.extra-toolbar-buttons","ext.gadget.switcher","ext.centralauth.centralautologin","ext.popups","ext.echo.centralauth","ext.uls.compactlinks","ext.uls.interface",
# "ext.cx.uls.quick.actions","wikibase.client.vector-2022","ext.growthExperiments.SuggestedEditSession"];</script>
# <script>(RLQ=window.RLQ||[]).push(function(){mw.loader.implement("user.options@12s5i",function($,jQuery,require,module){mw.user.tokens.set({"patrolToken":"+\\","watchToken":"+\\","csrfToken":"+\\"});});});</script>
# <link href="/w/load.php?lang=en&amp;modules=codex-search-styles%7Cext.cite.styles%7Cext.tmh.player.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cjquery.makeCollapsible.styles%7Cskins.vector.icons%2Cstyles%7Cwikibase.client.init&amp;only=styles&amp;skin=vector-2022" rel="stylesheet"/>
# <script async="" src="/w/load.php?lang=en&amp;modules=startup&amp;only=scripts&amp;raw=1&amp;skin=vector-2022"></script>
# <meta content="" name="ResourceLoaderDynamicStyles"/>
# <link href="/w/load.php?lang=en&amp;modules=site.styles&amp;only=styles&amp;skin=vector-2022" rel="stylesheet"/>
# <meta content="MediaWiki 1.41.0-wmf.15" name="generator"/>
# <meta content="origin" name="referrer"/>
# <meta content="origin-when-crossorigin" name="referrer"/>
# <meta content="origin-when-cross-origin" name="referrer"/>
# <meta content="max-image-preview:standard" name="robots"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="https://upload.wikimedia.org/wikipedia/commons/thumb/6/66/Flag_of_Malaysia.svg/1200px-Flag_of_Malaysia.svg.png" property="og:image"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="600" property="og:image:height"/>
# <meta content="https://upload.wikimedia.org/wikipedia/commons/thumb/6/66/Flag_of_Malaysia.svg/800px-Flag_of_Malaysia.svg.png" property="og:image"/>
# <meta content="800" property="og:image:width"/>
# <meta content="400" property="og:image:height"/>
# <meta content="https://upload.wikimedia.org/wikipedia/commons/thumb/6/66/Flag_of_Malaysia.svg/640px-Flag_of_Malaysia.svg.png" property="og:image"/>
# <meta content="640" property="og:image:width"/>
# <meta content="320" property="og:image:height"/>
# <meta content="width=1000" name="viewport"/>
# <meta content="Malaysia - Wikipedia" property="og:title"/>
# <meta content="website" property="og:type"/>
# <link href="//upload.wikimedia.org" rel="preconnect"/>
# <link href="//en.m.wikipedia.org/wiki/Malaysia" media="only screen and (max-width: 720px)" rel="alternate"/>
# <link href="/static/apple-touch/wikipedia.png" rel="apple-touch-icon"/>
# <link href="/static/favicon/wikipedia.ico" rel="icon"/>
# <link href="/w/opensearch_desc.php" rel="search" title="Wikipedia (en)" type="application/opensearchdescription+xml"/>
# <link href="//en.wikipedia.org/w/api.php?action=rsd" rel="EditURI" type="application/rsd+xml"/>
# <link href="https://en.wikipedia.org/wiki/Malaysia" rel="canonical"/>
# <link href="https://creativecommons.org/licenses/by-sa/4.0/deed.en" rel="license"/>
# <link href="/w/index.php?title=Special:RecentChanges&amp;feed=atom" rel="alternate" title="Wikipedia Atom feed" type="application/atom+xml"/>
# <link href="//meta.wikimedia.org" rel="dns-prefetch">
# <link href="//login.wikimedia.org" rel="dns-prefetch"/>
# </link></head>
# <body class="skin-vector skin-vector-search-vue mediawiki ltr sitedir-ltr mw-hide-empty-elt ns-0 ns-subject page-Malaysia rootpage-Malaysia skin-vector-2022 action-view"><a class="mw-jump-link" href="#bodyContent">Jump to content</a>
# <div class="vector-header-container">
# <header class="vector-header mw-header">
# <div class="vector-header-start">
# <nav aria-label="Site" class="vector-main-menu-landmark" role="navigation">
# <div class="vector-menu vector-dropdown vector-menu-dropdown vector-main-menu-dropdown vector-button-flush-left vector-button-flush-right" id="vector-main-menu-dropdown">
# <input aria-haspopup="true" aria-label="Main menu" class="vector-dropdown-checkbox vector-menu-checkbox" data-event-name="ui.dropdown-vector-main-menu-dropdown" id="vector-main-menu-dropdown-checkbox" role="button" type="checkbox"/>
# <label aria-hidden="true" class="vector-dropdown-label vector-menu-heading cdx-button cdx-button--fake-button cdx-button--fake-button--enabled cdx-button--weight-quiet cdx-button--icon-only" for="vector-main-menu-dropdown-checkbox" id="vector-main-menu-dropdown-label">
# <span class="vector-icon mw-ui-icon-menu mw-ui-icon-wikimedia-menu"></span>
# <span class="vector-dropdown-label-text vector-menu-heading-label">Main menu</span>
# </label>
# <div class="vector-menu-content vector-dropdown-content">
# <div class="vector-unpinned-container" id="vector-main-menu-unpinned-container">
# <div class="vector-main-menu vector-pinnable-element" id="vector-main-menu">
# <div class="vector-pinnable-header vector-main-menu-pinnable-header vector-pinnable-header-unpinned" data-feature-name="main-menu-pinned" data-pinnable-element-id="vector-main-menu" data-pinned-container-id="vector-main-menu-pinned-container" data-unpinned-container-id="vector-main-menu-unpinned-container">
# <div class="vector-pinnable-header-label">Main menu</div>
# <button class="vector-pinnable-header-toggle-button vector-pinnable-header-pin-button" data-event-name="pinnable-header.vector-main-menu.pin">move to sidebar</button>
# <button class="vector-pinnable-header-toggle-button vector-pinnable-header-unpin-button" data-event-name="pinnable-header.vector-main-menu.unpin">hide</button>
# </div>
# <div class="vector-menu mw-portlet mw-portlet-navigation" id="p-navigation">
# <div class="vector-menu-heading">
# 		Navigation
# 	</div>
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list"><li class="mw-list-item" id="n-mainpage-description"><a accesskey="z" href="/wiki/Main_Page" title="Visit the main page [z]"><span>Main page</span></a></li><li class="mw-list-item" id="n-contents"><a href="/wiki/Wikipedia:Contents" title="Guides to browsing Wikipedia"><span>Contents</span></a></li><li class="mw-list-item" id="n-currentevents"><a href="/wiki/Portal:Current_events" title="Articles related to current events"><span>Current events</span></a></li><li class="mw-list-item" id="n-randompage"><a accesskey="x" href="/wiki/Special:Random" title="Visit a randomly selected article [x]"><span>Random article</span></a></li><li class="mw-list-item" id="n-aboutsite"><a href="/wiki/Wikipedia:About" title="Learn about Wikipedia and how it works"><span>About Wikipedia</span></a></li><li class="mw-list-item" id="n-contactpage"><a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us" title="How to contact Wikipedia"><span>Contact us</span></a></li><li class="mw-list-item" id="n-sitesupport"><a href="https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&amp;utm_medium=sidebar&amp;utm_campaign=C13_en.wikipedia.org&amp;uselang=en" title="Support us by donating to the Wikimedia Foundation"><span>Donate</span></a></li></ul>
# </div>
# </div>
# <div class="vector-menu mw-portlet mw-portlet-interaction" id="p-interaction">
# <div class="vector-menu-heading">
# 		Contribute
# 	</div>
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list"><li class="mw-list-item" id="n-help"><a href="/wiki/Help:Contents" title="Guidance on how to use and edit Wikipedia"><span>Help</span></a></li><li class="mw-list-item" id="n-introduction"><a href="/wiki/Help:Introduction" title="Learn how to edit Wikipedia"><span>Learn to edit</span></a></li><li class="mw-list-item" id="n-portal"><a href="/wiki/Wikipedia:Community_portal" title="The hub for editors"><span>Community portal</span></a></li><li class="mw-list-item" id="n-recentchanges"><a accesskey="r" href="/wiki/Special:RecentChanges" title="A list of recent changes to Wikipedia [r]"><span>Recent changes</span></a></li><li class="mw-list-item" id="n-upload"><a href="/wiki/Wikipedia:File_upload_wizard" title="Add images or other media for use on Wikipedia"><span>Upload file</span></a></li></ul>
# </div>
# </div>
# <div class="vector-main-menu-action vector-main-menu-action-lang-alert">
# <div class="vector-main-menu-action-item">
# <div class="vector-main-menu-action-heading vector-menu-heading">Languages</div>
# <div class="vector-main-menu-action-content vector-menu-content">
# <div class="mw-message-box cdx-message cdx-message--block mw-message-box-notice cdx-message--notice vector-language-sidebar-alert"><span class="cdx-message__icon"></span><div class="cdx-message__content">Language links are at the top of the page across from the title.</div></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </nav>
# <a class="mw-logo" href="/wiki/Main_Page">
# <img alt="" aria-hidden="true" class="mw-logo-icon" height="50" src="/static/images/icons/wikipedia.png" width="50"/>
# <span class="mw-logo-container">
# <img alt="Wikipedia" class="mw-logo-wordmark" src="/static/images/mobile/copyright/wikipedia-wordmark-en.svg" style="width: 7.5em; height: 1.125em;"/>
# <img alt="The Free Encyclopedia" class="mw-logo-tagline" height="13" src="/static/images/mobile/copyright/wikipedia-tagline-en.svg" style="width: 7.3125em; height: 0.8125em;" width="117"/>
# </span>
# </a>
# </div>
# <div class="vector-header-end">
# <div class="vector-search-box-vue vector-search-box-collapses vector-search-box-show-thumbnail vector-search-box-auto-expand-width vector-search-box" id="p-search" role="search">
# <a accesskey="f" class="cdx-button cdx-button--fake-button cdx-button--fake-button--enabled cdx-button--weight-quiet cdx-button--icon-only search-toggle" href="/wiki/Special:Search" id="" title="Search Wikipedia [f]"><span class="vector-icon mw-ui-icon-search mw-ui-icon-wikimedia-search"></span>
# <span>Search</span>
# </a>
# <div class="vector-typeahead-search-container">
# <div class="cdx-typeahead-search cdx-typeahead-search--show-thumbnail cdx-typeahead-search--auto-expand-width">
# <form action="/w/index.php" class="cdx-search-input cdx-search-input--has-end-button" id="searchform">
# <div class="cdx-search-input__input-wrapper" data-search-loc="header-moved" id="simpleSearch">
# <div class="cdx-text-input cdx-text-input--has-start-icon">
# <input accesskey="f" aria-label="Search Wikipedia" autocapitalize="sentences" class="cdx-text-input__input" id="searchInput" name="search" placeholder="Search Wikipedia" title="Search Wikipedia [f]" type="search"/>
# <span class="cdx-text-input__icon cdx-text-input__start-icon"></span>
# </div>
# <input name="title" type="hidden" value="Special:Search"/>
# </div>
# <button class="cdx-button cdx-search-input__end-button">Search</button>
# </form>
# </div>
# </div>
# </div>
# <nav aria-label="Personal tools" class="vector-user-links" role="navigation">
# <div class="vector-menu mw-portlet mw-portlet-vector-user-menu-overflow" id="p-vector-user-menu-overflow">
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list"><li class="user-links-collapsible-item mw-list-item" id="pt-createaccount-2"><a href="/w/index.php?title=Special:CreateAccount&amp;returnto=Malaysia" title="You are encouraged to create an account and log in; however, it is not mandatory"><span>Create account</span></a></li><li class="user-links-collapsible-item mw-list-item" id="pt-login-2"><a accesskey="o" href="/w/index.php?title=Special:UserLogin&amp;returnto=Malaysia" title="You're encouraged to log in; however, it's not mandatory. [o]"><span>Log in</span></a></li></ul>
# </div>
# </div>
# <div class="vector-menu vector-dropdown vector-menu-dropdown vector-user-menu vector-button-flush-right vector-user-menu-logged-out" id="vector-user-links-dropdown" title="Log in and more options">
# <input aria-haspopup="true" aria-label="Personal tools" class="vector-dropdown-checkbox vector-menu-checkbox" data-event-name="ui.dropdown-vector-user-links-dropdown" id="vector-user-links-dropdown-checkbox" role="button" type="checkbox">
# <label aria-hidden="true" class="vector-dropdown-label vector-menu-heading cdx-button cdx-button--fake-button cdx-button--fake-button--enabled cdx-button--weight-quiet cdx-button--icon-only" for="vector-user-links-dropdown-checkbox" id="vector-user-links-dropdown-label">
# <span class="vector-icon mw-ui-icon-ellipsis mw-ui-icon-wikimedia-ellipsis"></span>
# <span class="vector-dropdown-label-text vector-menu-heading-label">Personal tools</span>
# </label>
# <div class="vector-menu-content vector-dropdown-content">
# <div class="vector-menu mw-portlet mw-portlet-personal user-links-collapsible-item" id="p-personal" title="User menu">
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list"><li class="user-links-collapsible-item mw-list-item" id="pt-createaccount"><a href="/w/index.php?title=Special:CreateAccount&amp;returnto=Malaysia" title="You are encouraged to create an account and log in; however, it is not mandatory"><span class="vector-icon mw-ui-icon-userAdd mw-ui-icon-wikimedia-userAdd"></span> <span>Create account</span></a></li><li class="user-links-collapsible-item mw-list-item" id="pt-login"><a accesskey="o" href="/w/index.php?title=Special:UserLogin&amp;returnto=Malaysia" title="You're encouraged to log in; however, it's not mandatory. [o]"><span class="vector-icon mw-ui-icon-logIn mw-ui-icon-wikimedia-logIn"></span> <span>Log in</span></a></li></ul>
# </div>
# </div>
# <div class="vector-menu mw-portlet mw-portlet-user-menu-anon-editor" id="p-user-menu-anon-editor">
# <div class="vector-menu-heading">
# 		Pages for logged out editors <a aria-label="Learn more about editing" href="/wiki/Help:Introduction"><span>learn more</span></a>
# </div>
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list"><li class="mw-list-item" id="pt-anoncontribs"><a accesskey="y" href="/wiki/Special:MyContributions" title="A list of edits made from this IP address [y]"><span>Contributions</span></a></li><li class="mw-list-item" id="pt-anontalk"><a accesskey="n" href="/wiki/Special:MyTalk" title="Discussion about edits from this IP address [n]"><span>Talk</span></a></li></ul>
# </div>
# </div>
# </div>
# </input></div>
# </nav>
# </div>
# </header>
# </div>
# <div class="mw-page-container">
# <div class="mw-page-container-inner">
# <div class="vector-main-menu-container">
# <div id="mw-navigation">
# <nav aria-label="Site" class="vector-main-menu-landmark" id="mw-panel" role="navigation">
# <div class="vector-pinned-container" id="vector-main-menu-pinned-container">
# </div>
# </nav>
# </div>
# </div>
# <div class="vector-sitenotice-container">
# <div id="siteNotice"><!-- CentralNotice --></div>
# </div>
# <input class="vector-menu-checkbox" id="vector-toc-collapsed-checkbox" type="checkbox"/>
# <nav aria-label="Contents" class="mw-table-of-contents-container vector-toc-landmark vector-sticky-pinned-container" data-event-name="ui.sidebar-toc" id="mw-panel-toc" role="navigation">
# <div class="vector-pinned-container" id="vector-toc-pinned-container">
# <div class="vector-toc vector-pinnable-element" id="vector-toc">
# <div class="vector-pinnable-header vector-toc-pinnable-header vector-pinnable-header-pinned" data-feature-name="toc-pinned" data-pinnable-element-id="vector-toc">
# <h2 class="vector-pinnable-header-label">Contents</h2>
# <button class="vector-pinnable-header-toggle-button vector-pinnable-header-pin-button" data-event-name="pinnable-header.vector-toc.pin">move to sidebar</button>
# <button class="vector-pinnable-header-toggle-button vector-pinnable-header-unpin-button" data-event-name="pinnable-header.vector-toc.unpin">hide</button>
# </div>
# <ul class="vector-toc-contents" id="mw-panel-toc-list">
# <li class="vector-toc-list-item vector-toc-level-1" id="toc-mw-content-text">
# <a class="vector-toc-link" href="#">
# <div class="vector-toc-text">(Top)</div>
# </a>
# </li>
# <li class="vector-toc-list-item vector-toc-level-1 vector-toc-list-item-expanded" id="toc-Etymology">
# <a class="vector-toc-link" href="#Etymology">
# <div class="vector-toc-text">
# <span class="vector-toc-numb">1</span>Etymology</div>
# </a>
# <ul class="vector-toc-list" id="toc-Etymology-sublist">
# </ul>
# </li>
# <li class="vector-toc-list-item vector-toc-level-1 vector-toc-list-item-expanded" id="toc-History">
# <a class="vector-toc-link" href="#History">
# <div class="vector-toc-text">
# <span class="vector-toc-numb">2</span>History</div>
# </a>
# <ul class="vector-toc-list" id="toc-History-sublist">
# </ul>
# </li>
# <li class="vector-toc-list-item vector-toc-level-1 vector-toc-list-item-expanded" id="toc-Government_and_politics">
# <a class="vector-toc-link" href="#Government_and_politics">
# <div class="vector-toc-text">
# <span class="vector-toc-numb">3</span>Government and politics</div>
# </a>
# <button aria-controls="toc-Government_and_politics-sublist" class="cdx-button cdx-button--weight-quiet cdx-button--icon-only vector-toc-toggle">
# <span class="vector-icon vector-icon--x-small mw-ui-icon-wikimedia-expand"></span>
# <span>Toggle Government and politics subsection</span>
# </button>
# <ul class="vector-toc-list" id="toc-Government_and_politics-sublist">
# <li class="vector-toc-list-item vector-toc-level-2" id="toc-Administrative_divisions">
# <a class="vector-toc-link" href="#Administrative_divisions">
# <div class="vector-toc-text">
# <span class="vector-toc-numb">3.1</span>Administrative divisions</div>
# </a>
# <ul class="vector-toc-list" id="toc-Administrative_divisions-sublist">
# </ul>
# </li>
# <li class="vector-toc-list-item vector-toc-level-2" id="toc-Foreign_relations_and_military">
# <a class="vector-toc-link" href="#Foreign_relations_and_military">
# <div class="vector-toc-text">
# <span class="vector-toc-numb">3.2</span>Foreign relations and military</div>
# </a>
# <ul class="vector-toc-list" id="toc-Foreign_relations_and_military-sublist">
# </ul>
# </li>
# <li class="vector-toc-list-item vector-toc-level-2" id="toc-Human_rights">
# <a class="vector-toc-link" href="#Human_rights">
# <div class="vector-toc-text">
# <span class="vector-toc-numb">3.3</span>Human rights</div>
# </a>
# <ul class="vector-toc-list" id="toc-Human_rights-sublist">
# </ul>
# </li>
# </ul>
# </li>
# <li class="vector-toc-list-item vector-toc-level-1 vector-toc-list-item-expanded" id="toc-Geography">
# <a class="vector-toc-link" href="#Geography">
# <div class="vector-toc-text">
# <span class="vector-toc-numb">4</span>Geography</div>
# </a>
# <button aria-controls="toc-Geography-sublist" class="cdx-button cdx-button--weight-quiet cdx-button--icon-only vector-toc-toggle">
# <span class="vector-icon vector-icon--x-small mw-ui-icon-wikimedia-expand"></span>
# <span>Toggle Geography subsection</span>
# </button>
# <ul class="vector-toc-list" id="toc-Geography-sublist">
# <li class="vector-toc-list-item vector-toc-level-2" id="toc-Biodiversity_and_conservation">
# <a class="vector-toc-link" href="#Biodiversity_and_conservation">
# <div class="vector-toc-text">
# <span class="vector-toc-numb">4.1</span>Biodiversity and conservation</div>
# </a>
# <ul class="vector-toc-list" id="toc-Biodiversity_and_conservation-sublist">
# </ul>
# </li>
# </ul>
# </li>
# <li class="vector-toc-list-item vector-toc-level-1 vector-toc-list-item-expanded" id="toc-Economy">
# <a class="vector-toc-link" href="#Economy">
# <div class="vector-toc-text">
# <span class="vector-toc-numb">5</span>Economy</div>
# </a>
# <button aria-controls="toc-Economy-sublist" class="cdx-button cdx-button--weight-quiet cdx-button--icon-only vector-toc-toggle">
# <span class="vector-icon vector-icon--x-small mw-ui-icon-wikimedia-expand"></span>
# <span>Toggle Economy subsection</span>
# </button>
# <ul class="vector-toc-list" id="toc-Economy-sublist">
# <li class="vector-toc-list-item vector-toc-level-2" id="toc-Infrastructure">
# <a class="vector-toc-link" href="#Infrastructure">
# <div class="vector-toc-text">
# <span class="vector-toc-numb">5.1</span>Infrastructure</div>
# </a>
# <ul class="vector-toc-list" id="toc-Infrastructure-sublist">
# </ul>
# </li>
# </ul>
# </li>
# <li class="vector-toc-list-item vector-toc-level-1 vector-toc-list-item-expanded" id="toc-Demographics">
# <a class="vector-toc-link" href="#Demographics">
# <div class="vector-toc-text">
# <span class="vector-toc-numb">6</span>Demographics</div>
# </a>
# <button aria-controls="toc-Demographics-sublist" class="cdx-button cdx-button--weight-quiet cdx-button--icon-only vector-toc-toggle">
# <span class="vector-icon vector-icon--x-small mw-ui-icon-wikimedia-expand"></span>
# <span>Toggle Demographics subsection</span>
# </button>
# <ul class="vector-toc-list" id="toc-Demographics-sublist">
# <li class="vector-toc-list-item vector-toc-level-2" id="toc-Religion">
# <a class="vector-toc-link" href="#Religion">
# <div class="vector-toc-text">
# <span class="vector-toc-numb">6.1</span>Religion</div>
# </a>
# <ul class="vector-toc-list" id="toc-Religion-sublist">
# </ul>
# </li>
# <li class="vector-toc-list-item vector-toc-level-2" id="toc-Languages">
# <a class="vector-toc-link" href="#Languages">
# <div class="vector-toc-text">
# <span class="vector-toc-numb">6.2</span>Languages</div>
# </a>
# <ul class="vector-toc-list" id="toc-Languages-sublist">
# </ul>
# </li>
# <li class="vector-toc-list-item vector-toc-level-2" id="toc-Health">
# <a class="vector-toc-link" href="#Health">
# <div class="vector-toc-text">
# <span class="vector-toc-numb">6.3</span>Health</div>
# </a>
# <ul class="vector-toc-list" id="toc-Health-sublist">
# </ul>
# </li>
# <li class="vector-toc-list-item vector-toc-level-2" id="toc-Education">
# <a class="vector-toc-link" href="#Education">
# <div class="vector-toc-text">
# <span class="vector-toc-numb">6.4</span>Education</div>
# </a>
# <ul class="vector-toc-list" id="toc-Education-sublist">
# </ul>
# </li>
# </ul>
# </li>
# <li class="vector-toc-list-item vector-toc-level-1 vector-toc-list-item-expanded" id="toc-Culture">
# <a class="vector-toc-link" href="#Culture">
# <div class="vector-toc-text">
# <span class="vector-toc-numb">7</span>Culture</div>
# </a>
# <button aria-controls="toc-Culture-sublist" class="cdx-button cdx-button--weight-quiet cdx-button--icon-only vector-toc-toggle">
# <span class="vector-icon vector-icon--x-small mw-ui-icon-wikimedia-expand"></span>
# <span>Toggle Culture subsection</span>
# </button>
# <ul class="vector-toc-list" id="toc-Culture-sublist">
# <li class="vector-toc-list-item vector-toc-level-2" id="toc-Fine_arts">
# <a class="vector-toc-link" href="#Fine_arts">
# <div class="vector-toc-text">
# <span class="vector-toc-numb">7.1</span>Fine arts</div>
# </a>
# <ul class="vector-toc-list" id="toc-Fine_arts-sublist">
# </ul>
# </li>
# <li class="vector-toc-list-item vector-toc-level-2" id="toc-Cuisine">
# <a class="vector-toc-link" href="#Cuisine">
# <div class="vector-toc-text">
# <span class="vector-toc-numb">7.2</span>Cuisine</div>
# </a>
# <ul class="vector-toc-list" id="toc-Cuisine-sublist">
# </ul>
# </li>
# <li class="vector-toc-list-item vector-toc-level-2" id="toc-Media">
# <a class="vector-toc-link" href="#Media">
# <div class="vector-toc-text">
# <span class="vector-toc-numb">7.3</span>Media</div>
# </a>
# <ul class="vector-toc-list" id="toc-Media-sublist">
# </ul>
# </li>
# <li class="vector-toc-list-item vector-toc-level-2" id="toc-Holidays_and_festivals">
# <a class="vector-toc-link" href="#Holidays_and_festivals">
# <div class="vector-toc-text">
# <span class="vector-toc-numb">7.4</span>Holidays and festivals</div>
# </a>
# <ul class="vector-toc-list" id="toc-Holidays_and_festivals-sublist">
# </ul>
# </li>
# <li class="vector-toc-list-item vector-toc-level-2" id="toc-Sports">
# <a class="vector-toc-link" href="#Sports">
# <div class="vector-toc-text">
# <span class="vector-toc-numb">7.5</span>Sports</div>
# </a>
# <ul class="vector-toc-list" id="toc-Sports-sublist">
# </ul>
# </li>
# </ul>
# </li>
# <li class="vector-toc-list-item vector-toc-level-1 vector-toc-list-item-expanded" id="toc-See_also">
# <a class="vector-toc-link" href="#See_also">
# <div class="vector-toc-text">
# <span class="vector-toc-numb">8</span>See also</div>
# </a>
# <ul class="vector-toc-list" id="toc-See_also-sublist">
# </ul>
# </li>
# <li class="vector-toc-list-item vector-toc-level-1 vector-toc-list-item-expanded" id="toc-Notes">
# <a class="vector-toc-link" href="#Notes">
# <div class="vector-toc-text">
# <span class="vector-toc-numb">9</span>Notes</div>
# </a>
# <ul class="vector-toc-list" id="toc-Notes-sublist">
# </ul>
# </li>
# <li class="vector-toc-list-item vector-toc-level-1 vector-toc-list-item-expanded" id="toc-References">
# <a class="vector-toc-link" href="#References">
# <div class="vector-toc-text">
# <span class="vector-toc-numb">10</span>References</div>
# </a>
# <ul class="vector-toc-list" id="toc-References-sublist">
# </ul>
# </li>
# <li class="vector-toc-list-item vector-toc-level-1 vector-toc-list-item-expanded" id="toc-External_links">
# <a class="vector-toc-link" href="#External_links">
# <div class="vector-toc-text">
# <span class="vector-toc-numb">11</span>External links</div>
# </a>
# <ul class="vector-toc-list" id="toc-External_links-sublist">
# </ul>
# </li>
# </ul>
# </div>
# </div>
# </nav>
# <div class="mw-content-container">
# <main class="mw-body" id="content" role="main">
# <header class="mw-body-header vector-page-titlebar">
# <label aria-controls="vector-toc" class="cdx-button cdx-button--fake-button cdx-button--fake-button--enabled cdx-button--weight-quiet vector-button-flush-left cdx-button--icon-only" for="vector-toc-collapsed-checkbox" id="vector-toc-collapsed-button" role="button" tabindex="0" title="Table of Contents">
# <span class="vector-icon mw-ui-icon-wikimedia-listBullet"></span>
# <span>Toggle the table of contents</span>
# </label>
# <nav aria-label="Contents" class="vector-toc-landmark" role="navigation">
# <div class="vector-menu vector-dropdown vector-menu-dropdown vector-page-titlebar-toc vector-button-flush-left" id="vector-page-titlebar-toc">
# <input aria-haspopup="true" aria-label="Toggle the table of contents" class="vector-dropdown-checkbox vector-menu-checkbox" data-event-name="ui.dropdown-vector-page-titlebar-toc" id="vector-page-titlebar-toc-checkbox" role="button" type="checkbox">
# <label aria-hidden="true" class="vector-dropdown-label vector-menu-heading cdx-button cdx-button--fake-button cdx-button--fake-button--enabled cdx-button--weight-quiet cdx-button--icon-only" for="vector-page-titlebar-toc-checkbox" id="vector-page-titlebar-toc-label">
# <span class="vector-icon mw-ui-icon-listBullet mw-ui-icon-wikimedia-listBullet"></span>
# <span class="vector-dropdown-label-text vector-menu-heading-label">Toggle the table of contents</span>
# </label>
# <div class="vector-menu-content vector-dropdown-content">
# <div class="vector-unpinned-container" id="vector-page-titlebar-toc-unpinned-container">
# </div>
# </div>
# </input></div>
# </nav>
# <h1 class="firstHeading mw-first-heading" id="firstHeading"><span class="mw-page-title-main">Malaysia</span></h1>
# <div class="vector-menu vector-dropdown vector-menu-dropdown mw-portlet mw-portlet-lang" id="p-lang-btn">
# <input aria-haspopup="true" aria-label="Go to an article in another language. Available in 257 languages" class="vector-dropdown-checkbox vector-menu-checkbox mw-interlanguage-selector" data-event-name="ui.dropdown-p-lang-btn" id="p-lang-btn-checkbox" role="button" type="checkbox">
# <label aria-hidden="true" class="vector-dropdown-label vector-menu-heading cdx-button cdx-button--fake-button cdx-button--fake-button--enabled cdx-button--weight-quiet cdx-button--action-progressive mw-portlet-lang-heading-257" for="p-lang-btn-checkbox" id="p-lang-btn-label">
# <span class="vector-icon mw-ui-icon-language-progressive mw-ui-icon-wikimedia-language-progressive"></span>
# <span class="vector-dropdown-label-text vector-menu-heading-label">257 languages</span>
# </label>
# <div class="vector-menu-content vector-dropdown-content">
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list"><li class="interlanguage-link interwiki-ace mw-list-item"><a class="interlanguage-link-target" href="https://ace.wikipedia.org/wiki/Malaysia" hreflang="ace" lang="ace" title="Malaysia – Achinese"><span>Acèh</span></a></li><li class="interlanguage-link interwiki-kbd mw-list-item"><a class="interlanguage-link-target" href="https://kbd.wikipedia.org/wiki/%D0%9C%D1%8D%D0%BB%D0%B0%D0%B9%D0%B7%D0%B8%D1%8D" hreflang="kbd" lang="kbd" title="Мэлайзиэ – Kabardian"><span>Адыгэбзэ</span></a></li><li class="interlanguage-link interwiki-ady mw-list-item"><a class="interlanguage-link-target" href="https://ady.wikipedia.org/wiki/%D0%9C%D0%B0%D0%BB%D0%B0%D0%B9%D0%B7%D0%B8%D0%B5" hreflang="ady" lang="ady" title="Малайзие – Adyghe"><span>Адыгабзэ</span></a></li><li class="interlanguage-link interwiki-af mw-list-item"><a class="interlanguage-link-target" href="https://af.wikipedia.org/wiki/Maleisi%C3%AB" hreflang="af" lang="af" title="Maleisië – Afrikaans"><span>Afrikaans</span></a></li><li class="interlanguage-link interwiki-als mw-list-item"><a class="interlanguage-link-target" href="https://als.wikipedia.org/wiki/Malaysia" hreflang="gsw" lang="gsw" title="Malaysia – Swiss German"><span>Alemannisch</span></a></li><li class="interlanguage-link interwiki-am mw-list-item"><a class="interlanguage-link-target" href="https://am.wikipedia.org/wiki/%E1%88%9B%E1%88%8C%E1%8B%A2%E1%8B%AB" hreflang="am" lang="am" title="ማሌዢያ – Amharic"><span>አማርኛ</span></a></li><li class="interlanguage-link interwiki-smn mw-list-item"><a class="interlanguage-link-target" href="https://smn.wikipedia.org/wiki/Malesia" hreflang="smn" lang="smn" title="Malesia – Inari Sami"><span>Anarâškielâ</span></a></li><li class="interlanguage-link interwiki-anp mw-list-item"><a class="interlanguage-link-target" href="https://anp.wikipedia.org/wiki/%E0%A4%AE%E0%A4%B2%E0%A5%87%E0%A4%B6%E0%A4%BF%E0%A4%AF%E0%A4%BE" hreflang="anp" lang="anp" title="मलेशिया – Angika"><span>अंगिका</span></a></li><li class="interlanguage-link interwiki-ang mw-list-item"><a class="interlanguage-link-target" href="https://ang.wikipedia.org/wiki/Mal%C3%A6gsia" hreflang="ang" lang="ang" title="Malægsia – Old English"><span>Ænglisc</span></a></li><li class="interlanguage-link interwiki-ar mw-list-item"><a class="interlanguage-link-target" href="https://ar.wikipedia.org/wiki/%D9%85%D8%A7%D9%84%D9%8A%D8%B2%D9%8A%D8%A7" hreflang="ar" lang="ar" title="ماليزيا – Arabic"><span>العربية</span></a></li><li class="interlanguage-link interwiki-an mw-list-item"><a class="interlanguage-link-target" href="https://an.wikipedia.org/wiki/Malaisia" hreflang="an" lang="an" title="Malaisia – Aragonese"><span>Aragonés</span></a></li><li class="interlanguage-link interwiki-hyw mw-list-item"><a class="interlanguage-link-target" href="https://hyw.wikipedia.org/wiki/%D5%84%D5%A1%D5%AC%D5%A5%D5%A6%D5%AB%D5%A1" hreflang="hyw" lang="hyw" title="Մալեզիա – Western Armenian"><span>Արեւմտահայերէն</span></a></li><li class="interlanguage-link interwiki-frp mw-list-item"><a class="interlanguage-link-target" href="https://frp.wikipedia.org/wiki/Mal%C3%A8sie" hreflang="frp" lang="frp" title="Malèsie – Arpitan"><span>Arpetan</span></a></li><li class="interlanguage-link interwiki-as mw-list-item"><a class="interlanguage-link-target" href="https://as.wikipedia.org/wiki/%E0%A6%AE%E0%A6%BE%E0%A6%B2%E0%A6%AF%E0%A6%BC%E0%A7%87%E0%A6%9B%E0%A6%BF%E0%A6%AF%E0%A6%BC%E0%A6%BE" hreflang="as" lang="as" title="মালয়েছিয়া – Assamese"><span>অসমীয়া</span></a></li><li class="interlanguage-link interwiki-ast mw-list-item"><a class="interlanguage-link-target" href="https://ast.wikipedia.org/wiki/Malasia" hreflang="ast" lang="ast" title="Malasia – Asturian"><span>Asturianu</span></a></li><li class="interlanguage-link interwiki-awa mw-list-item"><a class="interlanguage-link-target" href="https://awa.wikipedia.org/wiki/%E0%A4%AE%E0%A4%B2%E0%A5%87%E0%A4%B6%E0%A4%BF%E0%A4%AF%E0%A4%BE" hreflang="awa" lang="awa" title="मलेशिया – Awadhi"><span> ...
# <div class="after-portlet after-portlet-lang"><span class="wb-langlinks-edit wb-langlinks-link"><a class="wbc-editpage" href="https://www.wikidata.org/wiki/Special:EntityPage/Q833#sitelinks-wikipedia" title="Edit interlanguage links">Edit links</a></span></div>
# </div>
# </div>
# </input></div>
# </header>
# <div class="vector-page-toolbar">
# <div class="vector-page-toolbar-container">
# <div id="left-navigation">
# <nav aria-label="Namespaces">
# <div class="vector-menu vector-menu-tabs mw-portlet mw-portlet-associated-pages" id="p-associated-pages">
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list">
# <li class="selected vector-tab-noicon mw-list-item" id="ca-nstab-main"><a accesskey="c" class="" data-mw="interface" href="/wiki/Malaysia" title="View the content page [c]"><span>Article</span></a>
# </li>
# <li class="vector-tab-noicon mw-list-item" id="ca-talk"><a accesskey="t" class="" data-mw="interface" href="/wiki/Talk:Malaysia" rel="discussion" title="Discuss improvements to the content page [t]"><span>Talk</span></a>
# </li>
# </ul>
# </div>
# </div>
# <div class="vector-menu vector-dropdown vector-menu-dropdown mw-portlet mw-portlet-variants emptyPortlet" id="p-variants">
# <input aria-haspopup="true" aria-label="Change language variant" class="vector-dropdown-checkbox vector-menu-checkbox" data-event-name="ui.dropdown-p-variants" id="p-variants-checkbox" role="button" type="checkbox"/>
# <label aria-hidden="true" class="vector-dropdown-label vector-menu-heading" for="p-variants-checkbox" id="p-variants-label">
# <span class="vector-dropdown-label-text vector-menu-heading-label">English</span>
# </label>
# <div class="vector-menu-content vector-dropdown-content">
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list"></ul>
# </div>
# </div>
# </div>
# </nav>
# </div>
# <div class="vector-collapsible" id="right-navigation">
# <nav aria-label="Views">
# <div class="vector-menu vector-menu-tabs mw-portlet mw-portlet-views" id="p-views">
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list">
# <li class="selected vector-tab-noicon mw-list-item" id="ca-view"><a class="" data-mw="interface" href="/wiki/Malaysia"><span>Read</span></a>
# </li>
# <li class="vector-tab-noicon mw-list-item" id="ca-viewsource"><a accesskey="e" class="" data-mw="interface" href="/w/index.php?title=Malaysia&amp;action=edit" title="This page is protected.
# You can view its source [e]"><span>View source</span></a>
# </li>
# <li class="vector-tab-noicon mw-list-item" id="ca-history"><a accesskey="h" class="" data-mw="interface" href="/w/index.php?title=Malaysia&amp;action=history" title="Past revisions of this page [h]"><span>View history</span></a>
# </li>
# </ul>
# </div>
# </div>
# </nav>
# <nav aria-label="More options" class="vector-page-tools-landmark">
# <div class="vector-menu vector-dropdown vector-menu-dropdown vector-page-tools-dropdown" id="vector-page-tools-dropdown">
# <input aria-haspopup="true" aria-label="Tools" class="vector-dropdown-checkbox vector-menu-checkbox" data-event-name="ui.dropdown-vector-page-tools-dropdown" id="vector-page-tools-dropdown-checkbox" role="button" type="checkbox"/>
# <label aria-hidden="true" class="vector-dropdown-label vector-menu-heading cdx-button cdx-button--fake-button cdx-button--fake-button--enabled cdx-button--weight-quiet" for="vector-page-tools-dropdown-checkbox" id="vector-page-tools-dropdown-label">
# <span class="vector-dropdown-label-text vector-menu-heading-label">Tools</span>
# </label>
# <div class="vector-menu-content vector-dropdown-content">
# <div class="vector-unpinned-container" id="vector-page-tools-unpinned-container">
# <div class="vector-page-tools vector-pinnable-element" id="vector-page-tools">
# <div class="vector-pinnable-header vector-page-tools-pinnable-header vector-pinnable-header-unpinned" data-feature-name="page-tools-pinned" data-pinnable-element-id="vector-page-tools" data-pinned-container-id="vector-page-tools-pinned-container" data-unpinned-container-id="vector-page-tools-unpinned-container">
# <div class="vector-pinnable-header-label">Tools</div>
# <button class="vector-pinnable-header-toggle-button vector-pinnable-header-pin-button" data-event-name="pinnable-header.vector-page-tools.pin">move to sidebar</button>
# <button class="vector-pinnable-header-toggle-button vector-pinnable-header-unpin-button" data-event-name="pinnable-header.vector-page-tools.unpin">hide</button>
# </div>
# <div class="vector-menu mw-portlet mw-portlet-cactions emptyPortlet vector-has-collapsible-items" id="p-cactions" title="More options">
# <div class="vector-menu-heading">
# 		Actions
# 	</div>
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list"><li class="selected vector-more-collapsible-item mw-list-item" id="ca-more-view"><a href="/wiki/Malaysia"><span>Read</span></a></li><li class="vector-more-collapsible-item mw-list-item" id="ca-more-viewsource"><a href="/w/index.php?title=Malaysia&amp;action=edit"><span>View source</span></a></li><li class="vector-more-collapsible-item mw-list-item" id="ca-more-history"><a href="/w/index.php?title=Malaysia&amp;action=history"><span>View history</span></a></li></ul>
# </div>
# </div>
# <div class="vector-menu mw-portlet mw-portlet-tb" id="p-tb">
# <div class="vector-menu-heading">
# 		General
# 	</div>
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list"><li class="mw-list-item" id="t-whatlinkshere"><a accesskey="j" href="/wiki/Special:WhatLinksHere/Malaysia" title="List of all English Wikipedia pages containing links to this page [j]"><span>What links here</span></a></li><li class="mw-list-item" id="t-recentchangeslinked"><a accesskey="k" href="/wiki/Special:RecentChangesLinked/Malaysia" rel="nofollow" title="Recent changes in pages linked from this page [k]"><span>Related changes</span></a></li><li class="mw-list-item" id="t-upload"><a accesskey="u" href="/wiki/Wikipedia:File_Upload_Wizard" title="Upload files [u]"><span>Upload file</span></a></li><li class="mw-list-item" id="t-specialpages"><a accesskey="q" href="/wiki/Special:SpecialPages" title="A list of all special pages [q]"><span>Special pages</span></a></li><li class="mw-list-item" id="t-permalink"><a href="/w/index.php?title=Malaysia&amp;oldid=1159764273" title="Permanent link to this revision of this page"><span>Permanent link</span></a></li><li class="mw-list-item" id="t-info"><a href="/w/index.php?title=Malaysia&amp;action=info" title="More information about this page"><span>Page information</span></a></li><li class="mw-list-item" id="t-cite"><a href="/w/index.php?title=Special:CiteThisPage&amp;page=Malaysia&amp;id=1159764273&amp;wpFormIdentifier=titleform" title="Information on how to cite this page"><span>Cite this page</span></a></li><li class="mw-list-item" id="t-wikibase"><a accesskey="g" href="https://www.wikidata.org/wiki/Special:EntityPage/Q833" title="Structured data on this page hosted by Wikidata [g]"><span>Wikidata item</span></a></li></ul>
# </div>
# </div>
# <div class="vector-menu mw-portlet mw-portlet-coll-print_export" id="p-coll-print_export">
# <div class="vector-menu-heading">
# 		Print/export
# 	</div>
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list"><li class="mw-list-item" id="coll-download-as-rl"><a href="/w/index.php?title=Special:DownloadAsPdf&amp;page=Malaysia&amp;action=show-download-screen" title="Download this page as a PDF file"><span>Download as PDF</span></a></li><li class="mw-list-item" id="t-print"><a accesskey="p" href="/w/index.php?title=Malaysia&amp;printable=yes" title="Printable version of this page [p]"><span>Printable version</span></a></li></ul>
# </div>
# </div>
# <div class="vector-menu mw-portlet mw-portlet-wikibase-otherprojects" id="p-wikibase-otherprojects">
# <div class="vector-menu-heading">
# 		In other projects
# 	</div>
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list"><li class="wb-otherproject-link wb-otherproject-commons mw-list-item"><a href="https://commons.wikimedia.org/wiki/Malaysia" hreflang="en"><span>Wikimedia Commons</span></a></li><li class="wb-otherproject-link wb-otherproject-wikinews mw-list-item"><a href="https://en.wikinews.org/wiki/Category:Malaysia" hreflang="en"><span>Wikinews</span></a></li><li class="wb-otherproject-link wb-otherproject-wikiquote mw-list-item"><a href="https://en.wikiquote.org/wiki/Malaysia" hreflang="en"><span>Wikiquote</span></a></li><li class="wb-otherproject-link wb-otherproject-wikivoyage mw-list-item"><a href="https://en.wikivoyage.org/wiki/Malaysia" hreflang="en"><span>Wikivoyage</span></a></li></ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </nav>
# </div>
# </div>
# </div>
# <div class="vector-column-end">
# <nav aria-label="More options" class="vector-page-tools-landmark vector-sticky-pinned-container">
# <div class="vector-pinned-container" id="vector-page-tools-pinned-container">
# </div>
# </nav>
# </div>
# <div aria-labelledby="firstHeading" class="vector-body" data-mw-ve-target-container="" id="bodyContent">
# <div class="vector-body-before-content">
# <div class="mw-indicators">
# ...
# /w/index.php?title=Seventeenth_East_Asia_Summit&action=edit&redlink=1
# /wiki/Australia
# /wiki/Brunei
# /wiki/Cambodia
# /wiki/China
# /wiki/India
# /wiki/Indonesia
# /wiki/Japan
# /wiki/Laos
# /wiki/Myanmar
# /wiki/New_Zealand
# /wiki/Philippines
# /wiki/Russia
# /wiki/Singapore
# /wiki/South_Korea
# /wiki/Thailand
# /wiki/United_States
# /wiki/Vietnam
# /wiki/Template:The_Commonwealth
# /wiki/Template_talk:The_Commonwealth
# https://en.wikipedia.org/w/index.php?title=Template:The_Commonwealth&action=edit
# /wiki/Member_states_of_the_Commonwealth_of_Nations
# /wiki/Commonwealth_of_Nations
# /wiki/List_of_sovereign_states
# /wiki/Antigua_and_Barbuda
# /wiki/Australia
# /wiki/The_Bahamas
# /wiki/Bangladesh
# /wiki/Barbados
# /wiki/Belize
# /wiki/Botswana
# /wiki/Brunei
# /wiki/Cameroon
# /wiki/Canada
# /wiki/Cyprus
# /wiki/Dominica
# /wiki/Eswatini
# /wiki/Fiji
# /wiki/Gabon
# /wiki/The_Gambia
# /wiki/Ghana
# /wiki/Grenada
# /wiki/Guyana
# /wiki/India
# /wiki/Jamaica
# /wiki/Kenya
# /wiki/Kiribati
# /wiki/Lesotho
# /wiki/Malawi
# /wiki/Maldives
# /wiki/Malta
# /wiki/Mauritius
# /wiki/Mozambique
# /wiki/Namibia
# /wiki/Nauru
# /wiki/New_Zealand
# /wiki/Nigeria
# /wiki/Pakistan
# /wiki/Papua_New_Guinea
# /wiki/Rwanda
# /wiki/Saint_Kitts_and_Nevis
# /wiki/Saint_Lucia
# /wiki/Saint_Vincent_and_the_Grenadines
# /wiki/Samoa
# /wiki/Seychelles
# /wiki/Sierra_Leone
# /wiki/Singapore
# /wiki/Solomon_Islands
# /wiki/South_Africa
# /wiki/Sri_Lanka
# /wiki/Tanzania
# /wiki/Togo
# /wiki/Tonga
# /wiki/Trinidad_and_Tobago
# /wiki/Tuvalu
# /wiki/Uganda
# /wiki/United_Kingdom
# /wiki/Vanuatu
# /wiki/Zambia
# /wiki/Associated_state
# /wiki/Cook_Islands
# /wiki/Niue
# /wiki/Dependent_territory
# /wiki/Australia
# /wiki/Ashmore_and_Cartier_Islands
# /wiki/Australian_Antarctic_Territory
# /wiki/Christmas_Island
# /wiki/Cocos_(Keeling)_Islands
# /wiki/Coral_Sea_Islands
# /wiki/Heard_Island_and_McDonald_Islands
# /wiki/Norfolk_Island
# /wiki/Realm_of_New_Zealand
# /wiki/Ross_Dependency
# /wiki/Tokelau
# /wiki/The_Crown
# /wiki/Akrotiri_and_Dhekelia
# /wiki/Anguilla
# /wiki/Bermuda
# /wiki/British_Antarctic_Territory
# /wiki/British_Indian_Ocean_Territory
# /wiki/British_Virgin_Islands
# /wiki/Cayman_Islands
# /wiki/Falkland_Islands
# /wiki/Gibraltar
# /wiki/Bailiwick_of_Guernsey
# /wiki/Isle_of_Man
# /wiki/Jersey
# /wiki/Montserrat
# /wiki/Pitcairn_Islands
# /wiki/Saint_Helena,_Ascension_and_Tristan_da_Cunha
# /wiki/South_Georgia_and_the_South_Sandwich_Islands
# /wiki/Turks_and_Caicos_Islands
# https://thecommonwealth.org/our-member-countries
# /wiki/Template:G-15_nations
# /wiki/Template_talk:G-15_nations
# https://en.wikipedia.org/w/index.php?title=Template:G-15_nations&action=edit
# /wiki/Group_of_15
# /w/index.php?title=1st_G-15_summit&action=edit&redlink=1
# /w/index.php?title=2nd_G-15_summit&action=edit&redlink=1
# /w/index.php?title=3rd_G-15_summit&action=edit&redlink=1
# /w/index.php?title=4th_G-15_summit&action=edit&redlink=1
# /w/index.php?title=5th_G-15_summit&action=edit&redlink=1
# /w/index.php?title=6th_G-15_summit&action=edit&redlink=1
# /w/index.php?title=7th_G-15_summit&action=edit&redlink=1
# /w/index.php?title=8th_G-15_summit&action=edit&redlink=1
# /wiki/9th_G-15_summit
# /w/index.php?title=10th_G-15_summit&action=edit&redlink=1
# /w/index.php?title=11th_G-15_summit&action=edit&redlink=1
# /wiki/12th_G-15_summit
# /wiki/13th_G-15_summit
# /wiki/14th_G-15_summit
# /wiki/15th_G-15_summit
# /wiki/Algeria
# /wiki/Argentina
# /wiki/Brazil
# /wiki/Chile
# /wiki/Egypt
# /wiki/India
# /wiki/Indonesia
# /wiki/Iran
# /wiki/Jamaica
# /wiki/Kenya
# /wiki/Mexico
# /wiki/Nigeria
# /wiki/Senegal
# /wiki/Sri_Lanka
# /wiki/Venezuela
# /wiki/Zimbabwe
# /wiki/Template:Asia-Pacific_Economic_Cooperation
# /wiki/Template_talk:Asia-Pacific_Economic_Cooperation
# https://en.wikipedia.org/w/index.php?title=Template:Asia-Pacific_Economic_Cooperation&action=edit
# /wiki/Asia-Pacific_Economic_Cooperation
# /wiki/APEC_Australia_1989
# /w/index.php?title=APEC_Singapore_1990&action=edit&redlink=1
# /w/index.php?title=APEC_Republic_of_Korea_1991&action=edit&redlink=1
# /w/index.php?title=APEC_Thailand_1992&action=edit&redlink=1
# /w/index.php?title=APEC_United_States_1993&action=edit&redlink=1
# /wiki/APEC_Indonesia_1994
# /w/index.php?title=APEC_Japan_1995&action=edit&redlink=1
# /wiki/APEC_Philippines_1996
# /wiki/APEC_Canada_1997
# /w/index.php?title=APEC_Malaysia_1998&action=edit&redlink=1
# /w/index.php?title=APEC_New_Zealand_1999&action=edit&redlink=1
# /w/index.php?title=APEC_Brunei_2000&action=edit&redlink=1
# /wiki/APEC_China_2001
# /wiki/APEC_Mexico_2002
# /wiki/APEC_Thailand_2003
# /wiki/APEC_Chile_2004
# /wiki/APEC_South_Korea_2005
# /wiki/APEC_Vietnam_2006
# /wiki/APEC_Australia_2007
# /wiki/APEC_Peru_2008
# /wiki/APEC_Singapore_2009
# /wiki/APEC_Japan_2010
# /wiki/APEC_United_States_2011
# /wiki/APEC_Russia_2012
# /wiki/APEC_Indonesia_2013
# /wiki/APEC_China_2014
# /wiki/APEC_Philippines_2015
# /wiki/APEC_Peru_2016
# /wiki/APEC_Vietnam_2017
# /wiki/APEC_Papua_New_Guinea_2018
# /wiki/APEC_Chile_2019
# /wiki/APEC_Malaysia_2020
# /wiki/APEC_New_Zealand_2021
# /wiki/APEC_Thailand_2022
# /wiki/APEC_Business_Travel_Card
# /wiki/APEC_blue
# /wiki/APEC_Climate_Center
# /wiki/APEC_Sculpture_Garden
# /wiki/APEC_Youth_Science_Festival
# /wiki/Special_administrative_regions_of_China
# /wiki/Template:Non-Aligned_Movement
# /wiki/Template_talk:Non-Aligned_Movement
# https://en.wikipedia.org/w/index.php?title=Template:Non-Aligned_Movement&action=edit
# /wiki/Non-Aligned_Movement
# /wiki/Non-Aligned_Movement#Members,_observers_and_guests
# /wiki/Cyprus_and_the_Non-Aligned_Movement
# /wiki/Egypt_and_the_Non-Aligned_Movement
# /wiki/India_and_the_Non-Aligned_Movement
# /wiki/Malta_and_the_Non-Aligned_Movement
# /wiki/Sri_Lanka_and_the_Non-Aligned_Movement
# /wiki/Tanzania_and_the_Non-Aligned_Movement
# /wiki/Yugoslavia_and_the_Non-Aligned_Movement
# /wiki/NAM_News_Network
# /wiki/Non-Aligned_News_Agencies_Pool
# /wiki/%22Josip_Broz_Tito%22_Art_Gallery_of_the_Nonaligned_Countries
# /wiki/Five_Principles_of_Peaceful_Coexistence
# /wiki/Template:Non-Aligned_Movement_Summits
# /wiki/Bandung_Conference
# /wiki/1st_Summit_of_the_Non-Aligned_Movement
# /wiki/2nd_Summit_of_the_Non-Aligned_Movement
# /wiki/3rd_Summit_of_the_Non-Aligned_Movement
# /wiki/4th_Summit_of_the_Non-Aligned_Movement
# /wiki/5th_Summit_of_the_Non-Aligned_Movement
# /wiki/6th_Summit_of_the_Non-Aligned_Movement
# /wiki/7th_Summit_of_the_Non-Aligned_Movement
# /wiki/8th_Summit_of_the_Non-Aligned_Movement
# /wiki/9th_Summit_of_the_Non-Aligned_Movement
# /wiki/10th_Summit_of_the_Non-Aligned_Movement
# /wiki/16th_Summit_of_the_Non-Aligned_Movement
# /wiki/18th_Summit_of_the_Non-Aligned_Movement
# /wiki/Josip_Broz_Tito#Non-Alignment
# /wiki/Socialist_Federal_Republic_of_Yugoslavia
# /wiki/Sukarno#Figurehead_president
# /wiki/Indonesia
# /wiki/Jawaharlal_Nehru
# /wiki/India
# /wiki/Kwame_Nkrumah
# /wiki/Ghana
# /wiki/Gamal_Abdel_Nasser#Adoption_of_neutralism
# /wiki/Egypt
# /wiki/Houari_Boumediene#Foreign_policy
# /wiki/Fidel_Castro#Foreign_wars_and_NAM_Presidency:_1975–1979
# /wiki/Nelson_Mandela#Foreign_affairs
# /wiki/Mohamed_Morsi#Non-Aligned_Movement
# /wiki/Nicol%C3%A1s_Maduro
# /wiki/Sirimavo_Bandaranaike
# /wiki/Template:Organisation_of_Islamic_Cooperation
# /wiki/Template_talk:Organisation_of_Islamic_Cooperation
# https://en.wikipedia.org/w/index.php?title=Template:Organisation_of_Islamic_Cooperation&action=edit
# /wiki/Organisation_of_Islamic_Cooperation
# /wiki/Afghanistan
# /wiki/Albania
# /wiki/Algeria
# /wiki/Azerbaijan
# /wiki/Bahrain
# /wiki/Bangladesh
# /wiki/Benin
# /wiki/Burkina_Faso
# /wiki/Brunei
# /wiki/Cameroon
# /wiki/Chad
# /wiki/Comoros
# /wiki/Djibouti
# /wiki/Egypt
# /wiki/Gabon
# /wiki/The_Gambia
# /wiki/Guinea
# /wiki/Guinea-Bissau
# /wiki/Guyana
# /wiki/Indonesia
# /wiki/Iran
# /wiki/Iraq
# /wiki/Ivory_Coast
# /wiki/Jordan
# /wiki/Kazakhstan
# /wiki/Kuwait
# /wiki/Kyrgyzstan
# /wiki/Lebanon
# /wiki/Libya
# /wiki/Maldives
# /wiki/Mali
# /wiki/Mauritania
# /wiki/Morocco
# /wiki/Mozambique
# /wiki/Niger
# /wiki/Nigeria
# /wiki/Oman
# /wiki/Pakistan
# /wiki/State_of_Palestine
# /wiki/Qatar
# /wiki/Saudi_Arabia
# /wiki/Senegal
# /wiki/Sierra_Leone
# /wiki/Somalia
# /wiki/Sudan
# /wiki/Suriname
# /wiki/Tajikistan
# /wiki/Togo
# /wiki/Tunisia
# /wiki/Turkey
# /wiki/Turkmenistan
# /wiki/Uganda
# /wiki/Uzbekistan
# /wiki/United_Arab_Emirates
# /wiki/Yemen
# /wiki/Syria
# /wiki/Bosnia_and_Herzegovina
# /wiki/Central_African_Republic
# /wiki/Northern_Cyprus
# /wiki/Russia
# /wiki/Thailand
# /wiki/Moro_National_Liberation_Front
# /wiki/Economic_Cooperation_Organization
# /wiki/African_Union
# /wiki/Arab_League
# /wiki/Non-Aligned_Movement
# /wiki/United_Nations
# /wiki/Template:Pacific_Islands_Forum_(PIF)
# /wiki/Template_talk:Pacific_Islands_Forum_(PIF)
# https://en.wikipedia.org/w/index.php?title=Template:Pacific_Islands_Forum_(PIF)&action=edit
# /wiki/Pacific_Islands_Forum
# /wiki/Australia
# /wiki/Cook_Islands
# /wiki/Fiji
# /wiki/French_Polynesia
# /wiki/Marshall_Islands
# /wiki/Federated_States_of_Micronesia
# /wiki/Nauru
# /wiki/New_Zealand
# /wiki/Niue
# /wiki/Palau
# /wiki/Papua_New_Guinea
# /wiki/New_Caledonia
# /wiki/Samoa
# /wiki/Solomon_Islands
# /wiki/Tonga
# /wiki/Tuvalu
# /wiki/Vanuatu
# /wiki/File:Pif_secretariat.jpg
# /wiki/Tokelau
# /wiki/American_Samoa
# /wiki/East_Timor
# /wiki/Guam
# /wiki/Northern_Mariana_Islands
# /wiki/Wallis_and_Futuna
# /wiki/African,_Caribbean_and_Pacific_Group_of_States
# /wiki/Asian_Development_Bank
# /wiki/Commonwealth_of_Nations
# /wiki/International_Organization_for_Migration
# /wiki/United_Nations
# /wiki/Western_and_Central_Pacific_Fisheries_Commission
# /wiki/World_Bank
# /wiki/Canada
# /wiki/China
# /wiki/Cuba
# /wiki/European_Union
# /wiki/France
# /wiki/Germany
# /wiki/India
# /wiki/Indonesia
# /wiki/Italy
# /wiki/Japan
# /wiki/South_Korea
# /wiki/Philippines
# /wiki/Spain
# /wiki/Thailand
# /wiki/Turkey
# /wiki/United_Kingdom
# /wiki/United_States
# /wiki/45th_Pacific_Islands_Forum
# /wiki/51st_Pacific_Islands_Forum
# /wiki/Kiribati
# /wiki/Help:Authority_control
# https://www.wikidata.org/wiki/Q833#identifiers
# http://id.worldcat.org/fast/1204590/
# https://isni.org/isni/0000000121775970
# https://viaf.org/viaf/128419926
# https://authority.bibsys.no/authority/rest/authorities/html/99056428
# http://catalogo.bne.es/uhtbin/authoritybrowse.cgi?action=display&authority_id=XX452375
# https://catalogue.bnf.fr/ark:/12148/cb11945050f
# https://data.bnf.fr/ark:/12148/cb11945050f
# https://cantic.bnc.cat/registre/981058616198106706
# https://d-nb.info/gnd/4037203-0
# http://uli.nli.org.il/F/?func=find-b&local_base=NLX10&find_code=UID&request=987007264941505171
# http://uli.nli.org.il/F/?func=find-b&local_base=NLX10&find_code=UID&request=987007554955605171
# https://id.loc.gov/authorities/n79022246
# https://id.loc.gov/authorities/sh85080109
# https://libris.kb.se/khwzxrd31q8xhb5
# https://id.ndl.go.jp/auth/ndlna/00567491
# https://aleph.nkp.cz/F/?func=find-c&local_base=aut&ccl_term=ica=ge129933&CON_LNG=ENG
# https://nla.gov.au/anbd.aut-an35323768
# https://lod.nl.go.kr/resource/KAB202014144
# https://musicbrainz.org/area/305d19c7-c040-349c-8d5f-6ac75d2d2a09
# https://ci.nii.ac.jp/author/DA03173300?l=en
# https://trove.nla.gov.au/people/911758
# http://esu.com.ua/search_articles.php?id=61047
# https://hls-dhs-dss.ch/fr/articles/003420
# https://catalog.archives.gov/id/10035733
# https://www.idref.fr/027400212
# https://islamansiklopedisi.org.tr/malezya
# https://geohack.toolforge.org/geohack.php?pagename=Malaysia&params=2_N_112_E_type:country_region:MY
# https://en.wikipedia.org/w/index.php?title=Malaysia&oldid=1159764273
# /wiki/Help:Category
# /wiki/Category:Malaysia
# /wiki/Category:Countries_in_Asia
# /wiki/Category:Member_states_of_ASEAN
# /wiki/Category:Malay-speaking_countries_and_territories
# /wiki/Category:Member_states_of_the_Organisation_of_Islamic_Cooperation
# /wiki/Category:Member_states_of_the_United_Nations
# /wiki/Category:Commonwealth_monarchies
# /wiki/Category:Developing_8_Countries_member_states
# /wiki/Category:Federal_monarchies
# /wiki/Category:Member_states_of_the_Commonwealth_of_Nations
# /wiki/Category:G15_nations
# /wiki/Category:Southeast_Asian_countries
# /wiki/Category:States_and_territories_established_in_1963
# /wiki/Category:World_War_II_sites
# /wiki/Category:1963_establishments_in_Malaysia
# /wiki/Category:Articles_containing_Malay_(macrolanguage)-language_text
# /wiki/Category:All_articles_lacking_reliable_references
# /wiki/Category:Articles_lacking_reliable_references_from_June_2022
# /wiki/Category:Harv_and_Sfn_no-target_errors
# /wiki/Category:Wikipedia_articles_incorporating_a_citation_from_the_1911_Encyclopaedia_Britannica_with_Wikisource_reference
# /wiki/Category:CS1_errors:_missing_periodical
# /wiki/Category:All_articles_with_dead_external_links
# /wiki/Category:Articles_with_dead_external_links_from_February_2023
# /wiki/Category:Articles_with_permanently_dead_external_links
# /wiki/Category:CS1_maint:_unfit_URL
# /wiki/Category:CS1_Malay-language_sources_(ms)
# /wiki/Category:CS1_Indonesian-language_sources_(id)
# /wiki/Category:Articles_with_short_description
# /wiki/Category:Short_description_matches_Wikidata
# /wiki/Category:Wikipedia_pages_semi-protected_against_vandalism
# /wiki/Category:Wikipedia_indefinitely_semi-protected_pages
# /wiki/Category:Good_articles
# /wiki/Category:Use_British_English_from_August_2019
# /wiki/Category:Use_dmy_dates_from_June_2023
# /wiki/Category:Pages_using_infobox_country_or_infobox_former_country_with_the_symbol_caption_or_type_parameters
# /wiki/Category:Articles_with_hAudio_microformats
# /wiki/Category:Pages_including_recorded_pronunciations
# /wiki/Category:Articles_containing_Sanskrit-language_text
# /wiki/Category:Articles_containing_Tamil-language_text
# /wiki/Category:Articles_containing_Portuguese-language_text
# /wiki/Category:Pages_using_multiple_image_with_auto_scaled_images
# /wiki/Category:All_articles_with_unsourced_statements
# /wiki/Category:Articles_with_unsourced_statements_from_January_2023
# /wiki/Category:Articles_with_unsourced_statements_from_October_2022
# /wiki/Category:Articles_containing_potentially_dated_statements_from_2016
# /wiki/Category:All_articles_containing_potentially_dated_statements
# /wiki/Category:Pages_using_largest_cities_with_class
# /wiki/Category:All_articles_that_are_too_technical
# /wiki/Category:Wikipedia_articles_that_are_too_technical_from_October_2022
# /wiki/Category:All_articles_needing_expert_attention
# /wiki/Category:Articles_needing_expert_attention_from_October_2022
# /wiki/Category:Articles_containing_potentially_dated_statements_from_June_2022
# /wiki/Category:Pages_using_Sister_project_links_with_hidden_wikidata
# /wiki/Category:Pages_using_Sister_project_links_with_default_search
# /wiki/Category:Articles_with_Curlie_links
# /wiki/Category:Articles_with_FAST_identifiers
# /wiki/Category:Articles_with_ISNI_identifiers
# /wiki/Category:Articles_with_VIAF_identifiers
# /wiki/Category:Articles_with_BIBSYS_identifiers
# /wiki/Category:Articles_with_BNE_identifiers
# /wiki/Category:Articles_with_BNF_identifiers
# /wiki/Category:Articles_with_BNFdata_identifiers
# /wiki/Category:Articles_with_CANTICN_identifiers
# /wiki/Category:Articles_with_GND_identifiers
# /wiki/Category:Articles_with_J9U_identifiers
# /wiki/Category:Articles_with_LCCN_identifiers
# /wiki/Category:Articles_with_Libris_identifiers
# /wiki/Category:Articles_with_NDL_identifiers
# /wiki/Category:Articles_with_NKC_identifiers
# /wiki/Category:Articles_with_NLA_identifiers
# /wiki/Category:Articles_with_NLK_identifiers
# /wiki/Category:Articles_with_MusicBrainz_area_identifiers
# /wiki/Category:Articles_with_CINII_identifiers
# /wiki/Category:Articles_with_Trove_identifiers
# /wiki/Category:Articles_with_EMU_identifiers
# /wiki/Category:Articles_with_HDS_identifiers
# /wiki/Category:Articles_with_NARA_identifiers
# /wiki/Category:Articles_with_SUDOC_identifiers
# /wiki/Category:Articles_with_TDV%C4%B0A_identifiers
# /wiki/Category:Coordinates_on_Wikidata
# https://creativecommons.org/licenses/by-sa/4.0/
# //creativecommons.org/licenses/by-sa/4.0/
# //foundation.wikimedia.org/wiki/Terms_of_Use
# //foundation.wikimedia.org/wiki/Privacy_policy
# //www.wikimediafoundation.org/
# https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Privacy_policy
# /wiki/Wikipedia:About
# /wiki/Wikipedia:General_disclaimer
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# https://foundation.wikimedia.org/wiki/Special:MyLanguage/Universal_Code_of_Conduct
# //en.m.wikipedia.org/w/index.php?title=Malaysia&mobileaction=toggle_view_mobile
# https://developer.wikimedia.org
# https://stats.wikimedia.org/#/en.wikipedia.org
# https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Cookie_statement
# https://wikimediafoundation.org/
# https://www.mediawiki.org/

# %%
# retrieve only desired list of articles by using regular expression  ^(/wiki/)((?!:).)*$"):
import requests
import re
from bs4 import BeautifulSoup

html = requests.get('http://en.wikipedia.org/wiki/Malaysia')
bs = BeautifulSoup(html.content, 'html.parser')


for link in bs.find('div', {'id':'bodyContent'}).find_all('a', href=re.compile('^(/wiki/)((?!:).)*$')):
    if 'href' in link.attrs:
        print(link.attrs['href'])
# Out:
# /wiki/Malesia
# /wiki/Flag_of_Malaysia
# /wiki/Coat_of_arms_of_Malaysia
# /wiki/Negaraku
# /wiki/Asia
# /wiki/ASEAN
# /wiki/Kuala_Lumpur
# /wiki/Putrajaya
# /wiki/Malaysian_language
# /wiki/Malaysian_English
# /wiki/Ethnic_group
# /wiki/Bumiputera_(Malaysia)
# /wiki/Malays_(ethnic_group)
# /wiki/Orang_Asli
# /wiki/Sabah
# /wiki/Sarawak
# /wiki/Malaysian_Chinese
# /wiki/Malaysian_Indian
# /wiki/Ethnic_origins_of_people_in_Malaysia
# /wiki/Islam_in_Malaysia
# /wiki/State_religion
# /wiki/Buddhism_in_Malaysia
# /wiki/Christianity_in_Malaysia
# /wiki/Hinduism_in_Malaysia
# /wiki/Chinese_folk_religion
# /wiki/Demonym
# /wiki/Malaysians
# /wiki/Politics_of_Malaysia
# /wiki/Federal_monarchy
# /wiki/Parliamentary_system
# /wiki/Elective_monarchy
# /wiki/Constitutional_monarchy
# /wiki/Yang_di-Pertuan_Agong
# /wiki/Abdullah_of_Pahang
# /wiki/Prime_Minister_of_Malaysia
# /wiki/Ismail_Sabri_Yaakob
# /wiki/Parliament_of_Malaysia
# /wiki/Independence
# /wiki/United_Kingdom
# /wiki/Merdeka_Day
# /wiki/Federation_of_Malaya
# /wiki/Sarawak_Self-government_Day
# /wiki/North_Borneo_Self-government_Day
# /wiki/Proclamation_of_Malaysia
# /wiki/Geography_of_Malaysia
# /wiki/List_of_countries_and_dependencies_by_area
# /wiki/Demographics_of_Malaysia
# /wiki/List_of_countries_and_dependencies_by_population
# /wiki/List_of_countries_and_dependencies_by_population_density
# /wiki/Gross_domestic_product
# /wiki/Purchasing_power_parity
# /wiki/List_of_countries_by_GDP_(PPP)
# /wiki/List_of_countries_by_GDP_(PPP)_per_capita
# /wiki/Gross_domestic_product
# /wiki/List_of_countries_by_GDP_(nominal)
# /wiki/List_of_countries_by_GDP_(nominal)_per_capita
# /wiki/Gini_coefficient
# /wiki/Human_Development_Index
# /wiki/List_of_countries_by_Human_Development_Index
# /wiki/Malaysian_ringgit
# /wiki/ISO_4217
# /wiki/Coordinated_Universal_Time
# /wiki/Malaysian_Standard_Time
# /wiki/Mains_electricity
# /wiki/Mains_electricity_by_country
# /wiki/Left-_and_right-hand_traffic
# /wiki/Telephone_numbers_in_Malaysia
# /wiki/%2B60
# /wiki/ISO_3166
# /wiki/Country_code_top-level_domain
# /wiki/.my
# /wiki/Southeast_Asia
# /wiki/Federation
# /wiki/Constitutional_monarchy
# /wiki/States_and_federal_territories_of_Malaysia
# /wiki/South_China_Sea
# /wiki/Peninsular_Malaysia
# /wiki/Borneo
# /wiki/East_Malaysia
# /wiki/Malaysia%E2%80%93Thailand_border
# /wiki/Thailand
# /wiki/Singapore
# /wiki/Vietnam
# /wiki/Indonesia
# /wiki/Brunei
# /wiki/Philippines
# /wiki/Kuala_Lumpur
# /wiki/Parliament_of_Malaysia
# /wiki/Government_of_Malaysia
# /wiki/Planned_community#Planned_capitals
# /wiki/Putrajaya
# /wiki/Government_of_Malaysia#Executive
# /wiki/Cabinet_of_Malaysia
# /wiki/List_of_federal_ministries_and_agencies_in_Malaysia
# /wiki/Judiciary_of_Malaysia
# /wiki/List_of_countries_by_population
# /wiki/Eurasia
# /wiki/Tanjung_Piai
# /wiki/Tropics
# /wiki/Megadiverse_countries
# /wiki/Wildlife_of_Malaysia
# /wiki/British_Malaya
# /wiki/Straits_Settlements
# /wiki/Malayan_Union
# /wiki/Federation_of_Malaya
# /wiki/Crown_colony
# /wiki/Crown_Colony_of_North_Borneo
# /wiki/Crown_Colony_of_Sarawak
# /wiki/Colony_of_Singapore
# /wiki/Malaysia_Day
# /wiki/Singapore_in_Malaysia
# /wiki/Proclamation_of_Singapore
# /wiki/Ethnic_groups_in_Malaysia
# /wiki/Culture_of_Malaysia
# /wiki/Malaysian_Malay
# /wiki/Malaysian_Chinese
# /wiki/Malaysian_Indian
# /wiki/Orang_Asal
# /wiki/Malaysian_language
# /wiki/Malay_language
# /wiki/Islam
# /wiki/Established_religion
# /wiki/Freedom_of_religion
# /wiki/Westminster_system
# /wiki/Common_law
# /wiki/Head_of_state
# /wiki/Elective_monarchy
# /wiki/Monarchies_of_Malaysia
# /wiki/Head_of_government
# /wiki/Prime_Minister_of_Malaysia
# /wiki/Gross_domestic_product
# /wiki/Medical_tourism_in_Malaysia
# /wiki/Newly_industrialised_country
# /wiki/Market_economy
# /wiki/List_of_countries_by_GDP_(nominal)
# /wiki/Association_of_Southeast_Asian_Nations
# /wiki/East_Asia_Summit
# /wiki/Organisation_of_Islamic_Cooperation
# /wiki/Asia-Pacific_Economic_Cooperation
# /wiki/Commonwealth_of_Nations
# /wiki/Non-Aligned_Movement
# /wiki/Malay_people
# /wiki/Malay_Archipelago
# /wiki/Sanskrit
# /wiki/Tamil_language
# /wiki/Pamalayu
# /wiki/Javanese_language
# /wiki/Toponym
# /wiki/Vayu_Purana
# /wiki/Malay_peninsula
# /wiki/Geographia
# /wiki/Golden_Chersonese
# /wiki/Yijing_(monk)
# /wiki/Melayu_Kingdom
# /wiki/Srivijaya
# /wiki/Malacca_Sultanate
# /wiki/Ethnonym
# /wiki/Islamisation
# /wiki/Ethnoreligious
# /wiki/Johor_Sultanate
# /wiki/Tanah_Melayu
# /wiki/Johann_Friedrich_Blumenbach
# /wiki/Maritime_Southeast_Asia
# /wiki/Malay_race
# /wiki/Jules_Dumont_d%27Urville
# /wiki/Oceania
# /wiki/Micronesia
# /wiki/Melanesia
# /wiki/Soci%C3%A9t%C3%A9_de_G%C3%A9ographie
# /wiki/Polynesia
# /wiki/George_Samuel_Windsor_Earl
# /wiki/Ethnoreligious_group
# /wiki/Austronesian_people
# /wiki/Southeast_Asia
# /wiki/Borneo
# /wiki/Federation_of_Malaya
# /wiki/Langkasuka
# /wiki/History_of_Malaysia
# /wiki/Malacca_Sultanate
# /wiki/Negritos
# /wiki/India
# /wiki/China
# /wiki/Hinduism
# /wiki/Buddhism
# /wiki/Sanskrit
# /wiki/Langkasuka
# /wiki/Srivijaya
# /wiki/Majapahit
# /wiki/Parameswara_(king)
# /wiki/Kingdom_of_Singapura
# /wiki/Malacca_Sultanate
# /wiki/Dutch%E2%80%93Portuguese_War
# /wiki/Malacca_City
# /wiki/Malacca
# /wiki/Portuguese_Malacca
# /wiki/Dutch_Malacca
# /wiki/British_Malaya
# /wiki/Penang_Island
# /wiki/East_India_Company
# /wiki/Anglo-Dutch_Treaty_of_1824
# /wiki/Crown_Colony_of_Labuan
# /wiki/Straits_Settlements
# /wiki/Pahang
# /wiki/Selangor
# /wiki/Perak
# /wiki/Negeri_Sembilan
# /wiki/Federated_Malay_States
# /wiki/Resident_(title)
# /wiki/Unfederated_Malay_States
# /wiki/Immigration
# /wiki/Sabah
# /wiki/North_Borneo
# /wiki/Sultanate_of_Brunei
# /wiki/Sultanate_of_Sulu
# /wiki/James_Brooke
# /wiki/White_Rajahs
# /wiki/Raj_of_Sarawak
# /wiki/Crown_Colony_of_Sarawak
# /wiki/Second_World_War
# /wiki/Japanese_Army
# /wiki/Japanese_invasion_of_Malaya
# /wiki/Japanese_occupation_of_Malaya
# /wiki/Japanese_occupation_of_British_Borneo
# /wiki/Japanese_occupation_of_Singapore
# /wiki/Malayan_Union
# /wiki/Malays_(ethnic_group)
# /wiki/Malaysian_Chinese
# /wiki/Colony_of_Singapore
# /wiki/Federation_of_Malaya
# /wiki/Francis_Light
# /wiki/Fort_Cornwallis
# /wiki/Penang
# /wiki/Malayan_Communist_Party
# /wiki/Malayan_Emergency
# /wiki/Commonwealth_of_Nations
# /wiki/Indonesia
# /wiki/Sukarno
# /wiki/Sarawak_United_Peoples%27_Party
# /wiki/Indonesia%E2%80%93Malaysia_confrontation
# /wiki/Communist_insurgency_in_Sarawak
# /wiki/Communist_insurgency_in_Malaysia_(1968%E2%80%9389)
# /wiki/Cross_border_attacks_in_Sabah
# /wiki/Piracy_in_the_Sulu_Sea
# /wiki/Singapore_in_Malaysia#Expulsion
# /wiki/13_May_Incident
# /wiki/Malaysian_New_Economic_Policy
# /wiki/Tun_Abdul_Razak
# /wiki/Bumiputera_(Malaysia)
# /wiki/Mahathir_Mohamad
# /wiki/Petronas_Towers
# /wiki/North%E2%80%93South_Expressway_(Malaysia)
# /wiki/MSC_Malaysia
# /wiki/Putrajaya
# /wiki/1997_Asian_Financial_Crisis
# /wiki/1MDB_scandal
# /wiki/Corruption_in_Malaysia
# /wiki/Najib_Razak
# /wiki/2018_Malaysian_general_election
# /wiki/2020%E2%80%9321_Malaysian_political_crisis
# /wiki/Economic_impact_of_the_COVID-19_pandemic_in_Malaysia
# /wiki/COVID-19_pandemic_in_Malaysia
# /wiki/Politics_of_Malaysia
# /wiki/Government_of_Malaysia
# /wiki/Parliament_of_Malaysia
# /wiki/Members_of_the_Dewan_Rakyat,_14th_Malaysian_Parliament
# /wiki/Federation
# /wiki/Constitutional_monarchy
# /wiki/Elective_monarchy
# /wiki/Westminster_system
# /wiki/British_Empire
# /wiki/Yang_di-Pertuan_Agong
# /wiki/Monarchies_of_Malaysia
# /wiki/Malay_states
# /wiki/Yang_di-Pertua_Negeri
# /wiki/Abdullah_of_Pahang
# /wiki/Constitution_of_Malaysia
# /wiki/1993_amendments_to_the_Constitution_of_Malaysia
# /wiki/Parliament_of_Malaysia
# /wiki/Lower_house
# /wiki/House_of_Representatives_of_Malaysia
# /wiki/Upper_house
# /wiki/Senate_of_Malaysia
# /wiki/First-past-the-post_voting
# /wiki/Elections_in_Malaysia
# /wiki/Voting_age
# /wiki/Democracy_Index
# /wiki/Perdana_Putra
# /wiki/Prime_Minister_of_Malaysia
# /wiki/Executive_branch
# /wiki/Cabinet_of_Malaysia
# /wiki/Prime_Minister_of_Malaysia
# /wiki/Cabinet_of_Malaysia
# /wiki/Head_of_government
# /wiki/2018_Malaysian_general_election
# /wiki/Pakatan_Harapan
# /wiki/Political_alliance
# /wiki/Mahathir_Mohamad
# /wiki/2020%E2%80%9321_Malaysian_political_crisis
# /wiki/Perikatan_Nasional
# /wiki/Muhyiddin_Yassin
# /wiki/Ismail_Sabri_Yaakob
# /wiki/Law_of_Malaysia
# /wiki/English_law
# /wiki/Judiciary_of_Malaysia
# /wiki/Federal_Court_of_Malaysia
# /wiki/Court_of_Appeal_of_Malaysia
# /wiki/High_Courts_of_Malaysia
# /wiki/Capital_punishment_in_Malaysia
# /wiki/Murder
# /wiki/Terrorism
# /wiki/Drug_trafficking
# /wiki/Kidnapping
# /wiki/Syariah_Court
# /wiki/Shariah_law
# /wiki/Family_law
# /wiki/LGBT_rights_in_Malaysia
# /wiki/Caning_in_Malaysia
# /wiki/Human_trafficking
# /wiki/Sex_trafficking_in_Malaysia
# /wiki/Affirmative_action#Malaysia
# /wiki/Malaysian_New_Economic_Policy
# /wiki/National_Development_Policy
# /wiki/Religion_in_Malaysia#Secularism
# /wiki/Pan-Malaysian_Islamic_Party
# /wiki/United_Malays_National_Organisation
# /wiki/Press_Freedom_Index
# /wiki/Perikatan_Nasional
# /wiki/Corruption_in_Malaysia
# /wiki/Freedom_House
# /wiki/United_States_Department_of_Justice
# /wiki/1Malaysia_Development_Berhad
# /wiki/Najib_Razak
# /wiki/1Malaysia_Development_Berhad_scandal
# /wiki/States_and_federal_territories_of_Malaysia
# /wiki/Divisions_of_Malaysia
# /wiki/Districts_of_Malaysia
# /wiki/Perlis
# /wiki/Kedah
# /wiki/Penang
# /wiki/Kelantan
# /wiki/Terengganu
# /wiki/Perak
# /wiki/Selangor
# /wiki/Negeri_Sembilan
# /wiki/Malacca
# /wiki/Johor
# /wiki/Pahang
# /wiki/Sarawak
# /wiki/Sabah
# /wiki/Labuan
# /wiki/Kuala_Lumpur
# /wiki/Putrajaya
# /wiki/West_Malaysia
# /wiki/East_Malaysia
# /wiki/States_of_Malaysia
# /wiki/Federal_Territories_(Malaysia)
# /wiki/South_China_Sea
# /wiki/Strait_of_Malacca
# /wiki/Gulf_of_Thailand
# /wiki/Sulu_Sea
# /wiki/Celebes_Sea
# /wiki/Brunei
# /wiki/Indonesia
# /wiki/Indonesia
# /wiki/Indonesia
# /wiki/Philippines
# /wiki/Singapore
# /wiki/Thailand
# /wiki/Federation
# /wiki/Peninsular_Malaysia
# /wiki/East_Malaysia
# /wiki/Districts_of_Malaysia
# /wiki/Mukim
# /wiki/Sabah
# /wiki/Sarawak
# /wiki/State_legislative_assemblies_of_Malaysia
# /wiki/Chief_Ministers_in_Malaysia
# /wiki/Malays_(ethnic_group)
# /wiki/Constitutional_convention_(political_custom)
# /wiki/Malay_states
# /wiki/Conference_of_Rulers
# /wiki/Royalties
# /wiki/Secession
# /wiki/Penang
# /wiki/Johor
# /wiki/Kelantan
# /wiki/Johor
# /wiki/Johor
# /wiki/Johor_Bahru
# /wiki/Kedah
# /wiki/Kedah
# /wiki/Alor_Setar
# /wiki/Kelantan
# /wiki/Kelantan
# /wiki/Kota_Bharu
# /wiki/Malacca
# /wiki/Malacca
# /wiki/Malacca_City
# /wiki/Negeri_Sembilan
# /wiki/Negeri_Sembilan
# /wiki/Seremban
# /wiki/Pahang
# /wiki/Pahang
# /wiki/Kuantan
# /wiki/Penang
# /wiki/Penang
# /wiki/George_Town,_Penang
# /wiki/Perak
# /wiki/Perak
# /wiki/Ipoh
# /wiki/Perlis
# /wiki/Perlis
# /wiki/Kangar
# /wiki/Selangor
# /wiki/Selangor
# /wiki/Shah_Alam
# /wiki/Terengganu
# /wiki/Terengganu
# /wiki/Kuala_Terengganu
# /wiki/Malaysia_Act_1963
# /wiki/Sabah
# /wiki/Sabah
# /wiki/Kota_Kinabalu
# /wiki/Sarawak
# /wiki/Sarawak
# /wiki/Kuching
# /wiki/Singapore
# /wiki/Singapore_in_Malaysia
# /wiki/Singapore_in_Malaysia
# /wiki/Kuala_Lumpur
# /wiki/Kuala_Lumpur
# /wiki/Labuan
# /wiki/Labuan
# /wiki/Putrajaya
# /wiki/Putrajaya
# /wiki/Foreign_relations_of_Malaysia
# /wiki/Malaysian_Armed_Forces
# /wiki/Mike_Pompeo
# /wiki/Putrajaya
# /wiki/Association_of_Southeast_Asian_Nations
# /wiki/Organisation_of_Islamic_Cooperation
# /wiki/United_Nations
# /wiki/Asia-Pacific_Economic_Cooperation
# /wiki/Developing_8_Countries
# /wiki/Non-Aligned_Movement
# /wiki/Commonwealth_of_Nations
# /wiki/East_Asia_Summit
# /wiki/Treaty_on_the_Prohibition_of_Nuclear_Weapons
# /wiki/Spratly_Islands
# /wiki/Territorial_disputes_in_the_South_China_Sea
# /wiki/China
# /wiki/Vietnam
# /wiki/Philippines
# /wiki/North_Borneo_dispute
# /wiki/Israel
# /wiki/International_Criminal_Court
# /wiki/Gaza_flotilla_raid
# /wiki/Israeli%E2%80%93Palestinian_peace_process
# /wiki/State_of_Palestine
# /wiki/Two-state_solution
# /wiki/United_Nations_Operation_in_the_Congo
# /wiki/United_Nations_Iran%E2%80%93Iraq_Military_Observer_Group
# /wiki/United_Nations_Transition_Assistance_Group
# /wiki/United_Nations_Transitional_Authority_in_Cambodia
# /wiki/United_Nations_Protection_Force
# /wiki/United_Nations_Operation_in_Somalia_II
# /wiki/United_Nations_Interim_Administration_Mission_in_Kosovo
# /wiki/United_Nations_Integrated_Mission_in_East_Timor
# /wiki/United_Nations_Interim_Force_in_Lebanon
# /wiki/Malaysian_Armed_Forces
# /wiki/Scorp%C3%A8ne-class_submarine
# /wiki/PT-91M
# /wiki/Malaysian_Army
# /wiki/M4_carbine
# /wiki/Sukhoi_Su-30MKM
# /wiki/Malaysian_Armed_Forces
# /wiki/Royal_Malaysian_Navy
# /wiki/Malaysian_Army
# /wiki/Royal_Malaysian_Air_Force
# /wiki/Five_Power_Defence_Arrangements
# /wiki/Piracy
# /wiki/Smuggling
# /wiki/Moro_conflict_in_the_Philippines
# /wiki/South_Thailand_insurgency
# /wiki/Geography_of_Malaysia
# /wiki/Tropics
# /wiki/Tropical_rainforest_climate
# /wiki/List_of_countries_and_outlying_territories_by_total_area
# /wiki/Borders_of_Malaysia
# /wiki/Indonesia
# /wiki/Brunei
# /wiki/Singapore
# /wiki/Maritime_boundary
# /wiki/Vietnam
# /wiki/Perlis_River
# /wiki/Golok_River
# /wiki/Tanjung_Piai
# /wiki/Johor
# /wiki/Strait_of_Malacca
# /wiki/Sumatra
# /wiki/South_China_Sea
# /wiki/Titiwangsa_Mountains
# /wiki/Mount_Korbu
# /wiki/Granite
# /wiki/Karst
# /wiki/Mount_Kinabalu
# /wiki/Borneo
# /wiki/Crocker_Range
# /wiki/Mount_Kinabalu
# /wiki/Kinabalu_National_Park
# /wiki/World_Heritage_Site
# /wiki/List_of_World_Heritage_Sites_in_Malaysia
# /wiki/Gunung_Mulu_National_Park
# /wiki/List_of_islands_of_Malaysia
# /wiki/Banggi_Island
# /wiki/Tropical_climate
# /wiki/Monsoon
# /wiki/Climate_change
# /wiki/Wildlife_of_Malaysia
# /wiki/Environmental_issues_in_Malaysia
# /wiki/List_of_national_parks_in_Malaysia
# /wiki/Oriental_pied_hornbill
# /wiki/Hawksbill_sea_turtle
# /wiki/Proboscis_monkey
# /wiki/Malayan_tiger
# /wiki/Convention_on_Biological_Diversity
# /wiki/Biodiversity_action_plan
# /wiki/Megadiverse_countries
# /wiki/Endemism
# /wiki/Exclusive_economic_zone_of_Malaysia
# /wiki/South_China_Sea
# /wiki/Coral_Triangle
# /wiki/Sipadan_island
# /wiki/Sulu_Sea
# /wiki/Ecotourism
# /wiki/Ascomycota
# /wiki/Basidiomycota
# /wiki/Bracket_fungi
# /wiki/Toadstool
# /wiki/Rafflesia
# /wiki/Dipterocarpaceae
# /wiki/Borneo_lowland_rain_forests
# /wiki/Mangroves
# /wiki/Vascular_plant
# /wiki/Rafflesia
# /wiki/Logging
# /wiki/Social_and_environmental_impact_of_palm_oil#Deforestation
# /wiki/Palm_oil_production_in_Malaysia
# /wiki/Deforestation_in_Malaysia
# /wiki/Begonia_eiromischa
# /wiki/Dynamite_fishing
# /wiki/Leatherback_turtle
# /wiki/Overconsumption
# /wiki/List_of_national_parks_of_Malaysia
# /wiki/Economy_of_Malaysia
# /wiki/PROTON_Holdings
# /wiki/Open_economy
# /wiki/Newly_industrialised_country
# /wiki/Market_economy
# /wiki/Australia
# /wiki/France
# /wiki/South_Korea
# /wiki/List_of_countries_by_GDP_(PPP)
# /wiki/Wawasan_2020
# /wiki/Najib_Razak
# /wiki/Government_Transformation_Programme_(Malaysia)
# /wiki/Economic_Transformation_Programme
# /wiki/HSBC
# /wiki/Credit_Suisse
# /wiki/1997_Asian_Financial_Crisis
# /wiki/Bamboo_network
# /wiki/Overseas_Chinese
# /wiki/Strait_of_Malacca
# /wiki/Tin
# /wiki/Rubber
# /wiki/Palm_oil
# /wiki/Petronas_Towers
# /wiki/Petronas
# /wiki/Tourism_in_Malaysia
# /wiki/Malaysia_Airlines_Flight_370
# /wiki/Malaysia_Airlines_Flight_17
# /wiki/Global_Retirement_Index
# /wiki/Malaysia_My_Second_Home
# /wiki/Visa_(document)
# /wiki/Islamic_banking
# /wiki/Malaysia_Defence_Industry_Council
# /wiki/Malaysian_Space_Agency
# /wiki/Sheikh_Muszaphar_Shukor
# /wiki/International_Space_Station
# /wiki/RazakSAT
# /wiki/Transport_in_Malaysia
# /wiki/Telecommunication
# /wiki/Port_Klang
# /wiki/Industrial_park
# /wiki/Technology_Park_Malaysia
# /wiki/Kulim_Hi-Tech_Park
# /wiki/Ground_water
# /wiki/Energy_policy_of_Malaysia
# /wiki/Tenaga_Nasional
# /wiki/Electric_utility
# /wiki/National_Grid_(Malaysia)
# /wiki/Electrical_substation#Transmission_substation
# /wiki/Kilovolts
# /wiki/Sarawak_Energy
# /wiki/Sabah_Electricity
# /wiki/Megawatts
# /wiki/GWh
# /wiki/List_of_power_stations_in_Malaysia
# /wiki/Asia-Pacific
# /wiki/North%E2%80%93South_Expressway_(Malaysia)
# /wiki/KTM_Class_91
# /wiki/KTM_Class_92
# /wiki/Kuala_Lumpur_International_Airport
# /wiki/Malaysian_Federal_Roads_System
# /wiki/Asphalt_concrete
# /wiki/Skudai%E2%80%93Pontian_Highway
# /wiki/Concrete
# /wiki/Federal_Highway,_Malaysia
# /wiki/Asphalt
# /wiki/North%E2%80%93South_Expressway_(Malaysia)
# /wiki/Kuala_Lumpur
# /wiki/Penang
# /wiki/Johor_Bahru
# /wiki/Pan-Borneo_Highway
# /wiki/Trunk_road
# /wiki/Dual_carriageway
# /wiki/Rail_transport_in_Malaysia
# /wiki/Double_track
# /wiki/Electrified_railways
# /wiki/Heavy_rail
# /wiki/Keretapi_Tanah_Melayu
# /wiki/Light_rapid_transit
# /wiki/Monorail
# /wiki/Rapid_Rail
# /wiki/Funicular
# /wiki/Penang_Hill_Railway
# /wiki/Commuter_rail
# /wiki/Kuala_Lumpur_International_Airport
# /wiki/Rapid_transit
# /wiki/KVMRT
# /wiki/State_Railway_of_Thailand
# /wiki/Burma_Railway
# /wiki/KTM_ETS
# /wiki/Inter-city_rail
# /wiki/Keretapi_Tanah_Melayu
# /wiki/KTM_Komuter
# /wiki/Padang_Besar,_Malaysia
# /wiki/Gemas
# /wiki/Johor_Bahru
# /wiki/List_of_airports_in_Malaysia
# /wiki/Flag_carrier
# /wiki/Malaysia_Airlines
# /wiki/AirAsia
# /wiki/Malindo_Air
# /wiki/MASwings
# /wiki/Firefly_(airline)
# /wiki/Berjaya_Air
# /wiki/MASkargo
# /wiki/Transmile_Air_Services
# /wiki/List_of_the_world%27s_busiest_airports_by_international_passenger_traffic
# /wiki/List_of_the_world%27s_busiest_airports_by_passenger_traffic
# /wiki/Kota_Kinabalu_International_Airport
# /wiki/Penang_International_Airport
# /wiki/Demographics_of_Malaysia
# /wiki/List_of_countries_by_population_in_2010
# /wiki/List_of_countries_and_territories_by_population_density
# /wiki/Age_group
# /wiki/Bumiputera_(Malaysia)
# /wiki/Malays_(ethnic_group)
# /wiki/Muslim
# /wiki/Dayak_people
# /wiki/Iban_people
# /wiki/Bidayuh
# /wiki/Orang_Ulu
# /wiki/Kadazan-Dusun
# /wiki/Melanau_people
# /wiki/Sama-Bajau
# /wiki/Orang_Asli
# /wiki/Malaysian_Chinese
# /wiki/Malaysian_Indians
# /wiki/Tamil_people
# /wiki/Malaysian_citizenship
# /wiki/Identity_document
# /wiki/MyKad
# /wiki/Education_in_Malaysia
# /wiki/Sijil_Pelajaran_Malaysia
# /wiki/Malaysian_Matriculation_Programme
# /wiki/Infant_mortality_rate
# /wiki/Healthcare_in_Malaysia
# /wiki/Crude_birth_rate
# /wiki/Julau_District
# /wiki/Selangau_District
# /wiki/Total_fertility_rate
# /wiki/Crude_death_rate
# /wiki/Perlis
# /wiki/Kuala_Penyu_District
# /wiki/Kinabatangan_District
# /wiki/RELA_Corps
# /wiki/List_of_cities_and_towns_in_Malaysia_by_population#Classification
# /wiki/List_of_cities_and_towns_in_Malaysia_by_population
# /wiki/List_of_cities_and_towns_in_Malaysia_by_population
# /wiki/States_and_federal_territories_of_Malaysia
# /wiki/List_of_cities_and_towns_in_Malaysia_by_population
# /wiki/List_of_cities_and_towns_in_Malaysia_by_population
# /wiki/List_of_cities_and_towns_in_Malaysia_by_population
# /wiki/States_and_federal_territories_of_Malaysia
# /wiki/List_of_cities_and_towns_in_Malaysia_by_population
# /wiki/Kuala_Lumpur
# /wiki/Seberang_Perai
# /wiki/Kuala_Lumpur
# /wiki/Federal_Territories_(Malaysia)
# /wiki/Shah_Alam
# /wiki/Selangor
# /wiki/Kajang
# /wiki/Klang_(city)
# /wiki/Seberang_Perai
# /wiki/Penang
# /wiki/Iskandar_Puteri
# /wiki/Johor
# /wiki/Kajang
# /wiki/Selangor
# /wiki/Seremban
# /wiki/Negeri_Sembilan
# /wiki/Klang_(city)
# /wiki/Selangor
# /wiki/Johor_Bahru
# /wiki/Johor
# /wiki/Subang_Jaya
# /wiki/Selangor
# /wiki/Malacca_City
# /wiki/Malacca
# /wiki/George_Town,_Penang
# /wiki/Penang
# /wiki/Ampang_Jaya
# /wiki/Selangor
# /wiki/Ipoh
# /wiki/Perak
# /wiki/Kota_Kinabalu
# /wiki/Sabah
# /wiki/Petaling_Jaya
# /wiki/Selangor
# /wiki/Sungai_Petani
# /wiki/Kedah
# /wiki/Kuching
# /wiki/Sarawak
# /wiki/Kuantan
# /wiki/Pahang
# /wiki/Selayang
# /wiki/Selangor
# /wiki/Alor_Setar
# /wiki/Kedah
# /wiki/Religion_in_Malaysia
# /wiki/Islam_in_Malaysia
# /wiki/Buddhism_in_Malaysia
# /wiki/Christianity_in_Malaysia
# /wiki/Hinduism_in_Malaysia
# /wiki/Confucianism
# /wiki/Taoism
# /wiki/Chinese_folk_religion
# /wiki/Sunni_Islam
# /wiki/Shafi%27i
# /wiki/Jurisprudence
# /wiki/Islam_in_Malaysia
# /wiki/Nondenominational_Muslims
# /wiki/Muslims
# /wiki/Syariah_Court
# /wiki/Madh%27hab
# /wiki/Marriage
# /wiki/Inheritance
# /wiki/Divorce
# /wiki/Apostasy
# /wiki/Religious_conversion
# /wiki/Courts_of_Malaysia
# /wiki/Languages_of_Malaysia
# /wiki/Malayic_languages
# /wiki/Bornean_languages
# /wiki/Aslian_languages
# /wiki/Land_Dayak_languages
# /wiki/Sama%E2%80%93Bajaw_languages
# /wiki/Philippine_languages
# /wiki/Varieties_of_Chinese
# /wiki/Malaysian_language
# /wiki/Malay_language
# /wiki/Malay_alphabet
# /wiki/Writing_system
# /wiki/Jawi_alphabet
# /wiki/Second_language
# /wiki/13_May_incident
# /wiki/Malaysian_English
# /wiki/British_English
# /wiki/Manglish
# /wiki/Tamil_language
# /wiki/Iban_language
# /wiki/Dusunic_languages
# /wiki/Coastal_Kadazan_language
# /wiki/Varieties_of_Chinese
# /wiki/Cantonese
# /wiki/Mandarin_Chinese
# /wiki/Hokkien
# /wiki/Hakka_Chinese
# /wiki/Hainanese
# /wiki/Fuzhou_dialect
# /wiki/Tamil_language
# /wiki/Thai_language
# /wiki/Caucasian_race
# /wiki/Creole_language
# /wiki/Portuguese-based_creole_languages#Southeast_Asia
# /wiki/Chavacano_language
# /wiki/Culture_of_Malaysia
# /wiki/Malay_people
# /wiki/Chinese_culture
# /wiki/Indian_Culture
# /wiki/Persian_culture
# /wiki/Arabic_culture
# /wiki/British_culture
# /wiki/Social_contract_(Malaysia)
# /wiki/Cultural_assimilation
# /wiki/Indonesia
# /wiki/Malaysian_art
# /wiki/Music_of_Malaysia
# /wiki/Malaysian_literature
# /wiki/Batik
# /wiki/Malaysian_batik
# /wiki/Kris
# /wiki/Beetle_nut
# /wiki/Batik
# /wiki/Songket
# /wiki/Kelantan
# /wiki/Pattani
# /wiki/Gendang
# /wiki/Gong
# /wiki/Agung
# /wiki/Kulintang
# /wiki/Mindanao
# /wiki/Kalimantan
# /wiki/Terengganu_Inscription_Stone
# /wiki/Malaysian_cuisine
# /wiki/Teh_tarik
# /wiki/Nasi_lemak
# /wiki/Drink
# /wiki/National_dish#National_dishes_and_foods_by_country
# /wiki/Spice_route
# /wiki/Sambal
# /wiki/Shrimp_paste
# /wiki/Stir_fried_water_spinach
# /wiki/Media_of_Malaysia
# /wiki/Radio_Televisyen_Malaysia
# /wiki/TV_Sarawak
# /wiki/Freedom_of_the_press
# /wiki/Democratic_Action_Party_(Malaysia)
# /wiki/Printing_Presses_and_Publications_Act
# /wiki/Public_holidays_in_Malaysia
# /wiki/Buddhist_temple
# /wiki/Kek_Lok_Si
# /wiki/Penang
# /wiki/Chinese_New_Year
# /wiki/Public_holidays
# /wiki/Hari_Merdeka
# /wiki/Malaysia_Day
# /wiki/Labour_Day
# /wiki/Muslim_holidays
# /wiki/Eid_al-Fitr
# /wiki/Eid_ul-Adha
# /wiki/Mawlid
# /wiki/Chinese_New_Year
# /wiki/Wesak
# /wiki/Deepavali
# /wiki/Thaipusam
# /wiki/Batu_Caves
# /wiki/Gawai_Dayak
# /wiki/Kaamatan
# /wiki/Sport_in_Malaysia
# /wiki/Silat_Melayu
# /wiki/Association_football
# /wiki/Badminton
# /wiki/Field_hockey
# /wiki/Bowls
# /wiki/Tennis
# /wiki/Squash_(sport)
# /wiki/Martial_arts
# /wiki/Horse_riding
# /wiki/Sailing
# /wiki/Skate_boarding
# /wiki/FIFA_World_Cup
# /wiki/Thomas_Cup
# /wiki/Squash_Racquets_Association_Of_Malaysia
# /wiki/Malaysia_men%27s_national_field_hockey_team
# /wiki/FIH_World_Rankings
# /wiki/Hockey_World_Cup
# /wiki/Merdeka_Stadium
# /wiki/Formula_One
# /wiki/Sepang_International_Circuit
# /wiki/Malaysian_Grand_Prix
# /wiki/Silat_Melayu
# /wiki/Ethnic_Malays
# /wiki/1956_Summer_Olympics
# /wiki/Olympic_Council_of_Malaysia
# /wiki/Malaysia_at_the_Olympics
# /wiki/1972_Munich_Olympic_Games
# /wiki/Commonwealth_Games
# /wiki/List_of_Malaysia-related_topics
# /wiki/Outline_of_Malaysia
# /wiki/National_Language_Act_1963/67
# /wiki/National_Language_Act_1963/67
# /wiki/Federal_Constitution_of_Malaysia
# /wiki/National_Language_Act_1963/67
# /wiki/ISBN_(identifier)
# /wiki/International_Monetary_Fund
# /wiki/ISBN_(identifier)
# /wiki/ISBN_(identifier)
# /wiki/International_Monetary_Fund
# /wiki/ISBN_(identifier)
# /wiki/Central_Intelligence_Agency
# /wiki/Utusan_Malaysia
# /wiki/ISBN_(identifier)
# /wiki/ISBN_(identifier)
# /wiki/ISBN_(identifier)
# /wiki/ISBN_(identifier)
# /wiki/ISBN_(identifier)
# /wiki/ISBN_(identifier)
# /wiki/ISBN_(identifier)
# /wiki/ISBN_(identifier)
# /wiki/ISBN_(identifier)
# /wiki/ISBN_(identifier)
# /wiki/Doi_(identifier)
# /wiki/JSTOR_(identifier)
# /wiki/S2CID_(identifier)
# /wiki/ISSN_(identifier)
# /wiki/Anthony_Reid_(academic)
# /wiki/ISBN_(identifier)
# /wiki/ISBN_(identifier)
# /wiki/Yale_University
# /wiki/Doi_(identifier)
# /wiki/S2CID_(identifier)
# /wiki/ISBN_(identifier)
# /wiki/ISBN_(identifier)
# /wiki/Stuff.co.nz
# /wiki/Doi_(identifier)
# /wiki/JSTOR_(identifier)
# /wiki/ISBN_(identifier)
# /wiki/ISBN_(identifier)
# /wiki/ISBN_(identifier)
# /wiki/ISBN_(identifier)
# /wiki/ISBN_(identifier)
# /wiki/Economist_Intelligence_Unit
# /wiki/Government_of_the_United_Kingdom
# /wiki/ISSN_(identifier)
# /wiki/The_Straits_Times
# /wiki/ISBN_(identifier)
# /wiki/ISBN_(identifier)
# /wiki/Journal_of_Southeast_Asian_Studies
# /wiki/Doi_(identifier)
# /wiki/S2CID_(identifier)
# /wiki/Doi_(identifier)
# /wiki/Astro_Awani
# /wiki/Ministry_of_Foreign_Affairs_(Malaysia)
# /wiki/The_Philippine_Star
# /wiki/The_Brunei_Times
# /wiki/Daily_Express_(Malaysia)
# /wiki/Ministry_of_National_Defense_of_the_People%27s_Republic_of_China
# /wiki/Press_Information_Bureau
# /wiki/Jane%27s_Information_Group
# /wiki/ISBN_(identifier)
# /wiki/ISBN_(identifier)
# /wiki/ISBN_(identifier)
# /wiki/ISBN_(identifier)
# /wiki/ISBN_(identifier)
# /wiki/ISBN_(identifier)
# /wiki/ISBN_(identifier)
# /wiki/ISBN_(identifier)
# /wiki/ISBN_(identifier)
# /wiki/Food_and_Agriculture_Organization
# /wiki/ISBN_(identifier)
# /wiki/ISBN_(identifier)
# /wiki/ISBN_(identifier)
# /wiki/Business_Insider
# /wiki/ISBN_(identifier)
# /wiki/ISBN_(identifier)
# /wiki/ISBN_(identifier)
# /wiki/ISBN_(identifier)
# /wiki/ISBN_(identifier)
# /wiki/The_Huffington_Post
# /wiki/ISBN_(identifier)
# /wiki/ISBN_(identifier)
# /wiki/ISBN_(identifier)
# /wiki/ISBN_(identifier)
# /wiki/ISBN_(identifier)
# /wiki/ISBN_(identifier)
# /wiki/Ambiga_Sreenevasan
# /wiki/ISBN_(identifier)
# /wiki/Pew_Research_Center
# /wiki/Doi_(identifier)
# /wiki/The_Sun_(Malaysia)
# /wiki/ISBN_(identifier)
# /wiki/ISBN_(identifier)
# /wiki/JSTOR_(identifier)
# /wiki/ISBN_(identifier)
# /wiki/Doi_(identifier)
# /wiki/ISBN_(identifier)
# /wiki/ISBN_(identifier)
# /wiki/ISBN_(identifier)
# /wiki/ISBN_(identifier)
# /wiki/ISBN_(identifier)
# /wiki/New_Sabah_Times
# /wiki/ISBN_(identifier)
# /wiki/ISBN_(identifier)
# /wiki/Kompas
# /wiki/ISBN_(identifier)
# /wiki/Doi_(identifier)
# /wiki/PMC_(identifier)
# /wiki/PMID_(identifier)
# /wiki/ISBN_(identifier)
# /wiki/ISBN_(identifier)
# /wiki/Encyclop%C3%A6dia_Britannica_Eleventh_Edition
# /wiki/Encyclop%C3%A6dia_Britannica_Eleventh_Edition
# /wiki/Encyclop%C3%A6dia_Britannica_Eleventh_Edition
# /wiki/Encyclop%C3%A6dia_Britannica_Eleventh_Edition
# /wiki/The_World_Factbook
# /wiki/Central_Intelligence_Agency
# /wiki/Curlie
# /wiki/BBC_News
# /wiki/History_of_Malaysia
# /wiki/Timeline_of_Malaysian_history
# /wiki/Prehistoric_Malaysia
# /wiki/Portuguese_Malacca
# /wiki/Dutch_Malacca
# /wiki/British_Malaya
# /wiki/British_Borneo
# /wiki/Japanese_occupation_of_Malaya
# /wiki/Japanese_occupation_of_British_Borneo
# /wiki/Malayan_Union
# /wiki/Federation_of_Malaya
# /wiki/Malayan_Emergency
# /wiki/Malaysia_Agreement
# /wiki/Indonesia%E2%80%93Malaysia_confrontation
# /wiki/Communist_insurgency_in_Sarawak
# /wiki/Singapore_in_Malaysia
# /wiki/Communist_insurgency_in_Malaysia_(1968%E2%80%9389)
# /wiki/13_May_incident
# /wiki/1988_Malaysian_constitutional_crisis
# /wiki/1997_Asian_financial_crisis#Malaysia
# /wiki/2018_Malaysian_general_election
# /wiki/2020%E2%80%9321_Malaysian_political_crisis
# /wiki/Coat_of_arms_of_Malaysia
# /wiki/Geography_of_Malaysia
# /wiki/List_of_districts_in_Malaysia
# /wiki/Divisions_of_Malaysia
# /wiki/East_Malaysia
# /wiki/Environment_of_Malaysia
# /wiki/List_of_World_Heritage_Sites_in_Malaysia
# /wiki/List_of_hill_stations_in_Malaysia
# /wiki/List_of_islands_of_Malaysia
# /wiki/List_of_lakes_of_Malaysia
# /wiki/List_of_mountains_in_Malaysia
# /wiki/List_of_national_parks_in_Malaysia
# /wiki/Peninsular_Malaysia
# /wiki/List_of_rivers_of_Malaysia
# /wiki/States_and_federal_territories_of_Malaysia
# /wiki/Politics_of_Malaysia
# /wiki/Cabinet_of_Malaysia
# /wiki/Shadow_Cabinet_of_Malaysia
# /wiki/Constitution_of_Malaysia
# /wiki/Elections_in_Malaysia
# /wiki/Foreign_relations_of_Malaysia
# /wiki/Government_of_Malaysia
# /wiki/Human_rights_in_Malaysia
# /wiki/Censorship_in_Malaysia
# /wiki/Judiciary_of_Malaysia
# /wiki/Law_of_Malaysia
# /wiki/Law_enforcement_in_Malaysia
# /wiki/Malaysian_Armed_Forces
# /wiki/Monarchies_of_Malaysia
# /wiki/Parliament_of_Malaysia
# /wiki/List_of_political_parties_in_Malaysia
# /wiki/Prime_Minister_of_Malaysia
# /wiki/State_legislative_assemblies_of_Malaysia
# /wiki/Yang_di-Pertuan_Agong
# /wiki/Economy_of_Malaysia
# /wiki/Agriculture_in_Malaysia
# /wiki/List_of_banks_in_Malaysia
# /wiki/Bank_Negara_Malaysia
# /wiki/Energy_policy_of_Malaysia
# /wiki/Malaysian_federal_budget
# /wiki/Malaysian_ringgit
# /wiki/List_of_Malaysian_states_by_GDP
# /wiki/Science_and_technology_in_Malaysia
# /wiki/Bursa_Malaysia
# /wiki/Telecommunications_in_Malaysia
# /wiki/Tourism_in_Malaysia
# /wiki/Transport_in_Malaysia
# /wiki/Trade_unions_in_Malaysia
# /wiki/Malaysia_and_the_World_Bank
# /wiki/Crime_in_Malaysia
# /wiki/Demographics_of_Malaysia
# /wiki/Education_in_Malaysia
# /wiki/Healthcare_in_Malaysia
# /wiki/Income_inequality_in_Malaysia
# /wiki/Languages_of_Malaysia
# /wiki/LGBT_rights_in_Malaysia
# /wiki/Malaysian_diaspora
# /wiki/Poverty_in_Malaysia
# /wiki/Religion_in_Malaysia
# /wiki/Sex_trafficking_in_Malaysia
# /wiki/Squatting_in_Malaysia
# /wiki/Water_supply_and_sanitation_in_Malaysia
# /wiki/Women_in_Malaysia
# /wiki/Culture_of_Malaysia
# /wiki/Malaysian_art
# /wiki/Cinema_of_Malaysia
# /wiki/Malaysian_cuisine
# /wiki/Folklore_of_Malaysia
# /wiki/Malaysian_literature
# /wiki/Ketuanan_Melayu
# /wiki/Media_of_Malaysia
# /wiki/Music_of_Malaysia
# /wiki/Malaysian_names
# /wiki/Public_holidays_in_Malaysia
# /wiki/Sport_in_Malaysia
# /wiki/Malayan_tiger
# /wiki/Negaraku
# /wiki/Coat_of_arms_of_Malaysia
# /wiki/Flag_of_Malaysia
# /wiki/Hibiscus_rosa-sinensis
# /wiki/Rukun_Negara
# /wiki/Outline_of_Malaysia
# /wiki/States_and_federal_territories_of_Malaysia
# /wiki/Johor
# /wiki/Kedah
# /wiki/Kelantan
# /wiki/Malacca
# /wiki/Negeri_Sembilan
# /wiki/Pahang
# /wiki/Penang
# /wiki/Perak
# /wiki/Perlis
# /wiki/Sabah
# /wiki/Sarawak
# /wiki/Selangor
# /wiki/Terengganu
# /wiki/Federal_Territories_of_Malaysia
# /wiki/Kuala_Lumpur
# /wiki/Labuan
# /wiki/Putrajaya
# /wiki/Singapore_in_Malaysia
# /wiki/Monarchy
# /wiki/List_of_current_sovereign_monarchs
# /wiki/List_of_current_constituent_monarchs
# /wiki/Absolute_monarchy
# /wiki/Constitutional_monarchy
# /wiki/Diarchy
# /wiki/Elective_monarchy
# /wiki/Federal_monarchy
# /wiki/Hereditary_monarchy
# /wiki/Regent
# /wiki/Monarchies_in_Africa
# /wiki/List_of_monarchs_of_Eswatini
# /wiki/List_of_monarchs_of_Lesotho
# /wiki/List_of_rulers_of_Morocco
# /wiki/List_of_current_constituent_African_monarchs
# /wiki/Monarchies_in_the_Americas
# /wiki/Monarchy_of_Antigua_and_Barbuda
# /wiki/Monarchy_of_the_Bahamas
# /wiki/Monarchy_of_Barbados
# /wiki/Monarchy_of_Belize
# /wiki/Monarchy_of_Canada
# /wiki/Monarchy_of_Grenada
# /wiki/Monarchy_of_Jamaica
# /wiki/Monarchy_of_Saint_Kitts_and_Nevis
# /wiki/Monarchy_of_Saint_Lucia
# /wiki/Monarchy_of_Saint_Vincent_and_the_Grenadines
# /wiki/Monarchies_in_Asia
# /wiki/King_of_Bahrain
# /wiki/House_of_Wangchuck
# /wiki/List_of_Sultans_of_Brunei
# /wiki/List_of_monarchs_of_Cambodia
# /wiki/Emperor_of_Japan
# /wiki/List_of_kings_of_Jordan
# /wiki/Emir_of_Kuwait
# /wiki/Yang_di-Pertuan_Agong
# /wiki/List_of_rulers_of_Oman
# /wiki/List_of_Amirs_of_Qatar
# /wiki/King_of_Saudi_Arabia
# /wiki/Monarchy_of_Thailand
# /wiki/President_of_the_United_Arab_Emirates
# /wiki/List_of_current_constituent_Asian_monarchs
# /wiki/Monarchies_in_Europe
# /wiki/Co-Princes_of_Andorra
# /wiki/Monarchy_of_Belgium
# /wiki/Monarchy_of_Denmark
# /wiki/Monarchy_of_Liechtenstein
# /wiki/Monarchy_of_Luxembourg
# /wiki/Monarchy_of_Monaco
# /wiki/Monarchy_of_the_Netherlands
# /wiki/Monarchy_of_Norway
# /wiki/Monarchy_of_Spain
# /wiki/Monarchy_of_Sweden
# /wiki/Monarchy_of_the_United_Kingdom
# /wiki/List_of_sovereigns_of_Vatican_City_State
# /wiki/Monarchies_in_Oceania
# /wiki/Monarchy_of_Australia
# /wiki/Monarchy_of_New_Zealand
# /wiki/Monarchy_in_the_Cook_Islands
# /wiki/List_of_Niuean_monarchs
# /wiki/Monarchy_of_Papua_New_Guinea
# /wiki/Monarchy_of_Solomon_Islands
# /wiki/List_of_monarchs_of_Tonga
# /wiki/Monarchy_of_Tuvalu
# /wiki/Southeast_Asia
# /wiki/Sovereign_state
# /wiki/Brunei
# /wiki/Cambodia
# /wiki/East_Timor
# /wiki/Indonesia
# /wiki/Laos
# /wiki/Myanmar
# /wiki/Philippines
# /wiki/Singapore
# /wiki/Thailand
# /wiki/Vietnam
# /wiki/Territory
# /wiki/India
# /wiki/Andaman_and_Nicobar_Islands
# /wiki/Australia
# /wiki/Christmas_Island
# /wiki/Cocos_(Keeling)_Islands
# /wiki/List_of_sovereign_states_and_dependent_territories_in_Asia
# /wiki/Asia
# /wiki/Sovereign_state
# /wiki/Afghanistan
# /wiki/Armenia
# /wiki/Azerbaijan
# /wiki/Bahrain
# /wiki/Bangladesh
# /wiki/Bhutan
# /wiki/Brunei
# /wiki/Cambodia
# /wiki/China
# /wiki/Cyprus
# /wiki/East_Timor
# /wiki/Egypt
# /wiki/Georgia_(country)
# /wiki/India
# /wiki/Indonesia
# /wiki/Iran
# /wiki/Iraq
# /wiki/Israel
# /wiki/Japan
# /wiki/Jordan
# /wiki/Kazakhstan
# /wiki/North_Korea
# /wiki/South_Korea
# /wiki/Kuwait
# /wiki/Kyrgyzstan
# /wiki/Laos
# /wiki/Lebanon
# /wiki/Maldives
# /wiki/Mongolia
# /wiki/Myanmar
# /wiki/Nepal
# /wiki/Oman
# /wiki/Pakistan
# /wiki/Philippines
# /wiki/Qatar
# /wiki/Russia
# /wiki/Saudi_Arabia
# /wiki/Singapore
# /wiki/Sri_Lanka
# /wiki/Syria
# /wiki/Tajikistan
# /wiki/Thailand
# /wiki/Turkey
# /wiki/Turkmenistan
# /wiki/United_Arab_Emirates
# /wiki/Uzbekistan
# /wiki/Vietnam
# /wiki/Yemen
# /wiki/List_of_states_with_limited_recognition
# /wiki/Abkhazia
# /wiki/Republic_of_Artsakh
# /wiki/Northern_Cyprus
# /wiki/State_of_Palestine
# /wiki/South_Ossetia
# /wiki/Taiwan
# /wiki/Dependent_territory
# /wiki/Special_administrative_regions_of_China
# /wiki/Christmas_Island
# /wiki/Cocos_(Keeling)_Islands
# /wiki/Hong_Kong
# /wiki/Macau
# /wiki/Akrotiri_and_Dhekelia
# /wiki/British_Indian_Ocean_Territory
# /wiki/ASEAN
# /wiki/ASEAN_Charter
# /wiki/ASEAN_Free_Trade_Area#The_Common_Effective_Preferential_Tariff_(CEPT)_scheme
# /wiki/ASEAN_Declaration
# /wiki/Organisations_associated_with_the_Association_of_Southeast_Asian_Nations
# /wiki/Secretary_General_of_the_Association_of_Southeast_Asian_Nations
# /wiki/Treaty_of_Amity_and_Cooperation_in_Southeast_Asia
# /wiki/Visa_policy_of_ASEAN_members
# /wiki/The_ASEAN_Way
# /wiki/Emblem_of_the_Association_of_Southeast_Asian_Nations
# /wiki/Flag_of_the_Association_of_Southeast_Asian_Nations
# /wiki/ASEAN_Song_of_Unity
# /wiki/Member_states_of_the_Association_of_Southeast_Asian_Nations
# /wiki/Brunei
# /wiki/Cambodia
# /wiki/Indonesia
# /wiki/Laos
# /wiki/Myanmar
# /wiki/Philippines
# /wiki/Singapore
# /wiki/Thailand
# /wiki/Vietnam
# /wiki/Enlargement_of_the_Association_of_Southeast_Asian_Nations
# /wiki/Papua_New_Guinea
# /wiki/Accession_of_Papua_New_Guinea_to_the_Association_of_Southeast_Asian_Nations
# /wiki/East_Timor
# /wiki/Accession_of_East_Timor_to_the_Association_of_Southeast_Asian_Nations
# /wiki/ASEAN_Summit
# /wiki/2017_ASEAN_Summits
# /wiki/East_Asia_Summit
# /wiki/ASEAN%E2%80%93Republic_of_Korea_Commemorative_Summit
# /wiki/ASEAN%E2%80%93India_Commemorative_Summit
# /wiki/ASEAN_Free_Trade_Area#ASEAN_Plus_Three
# /wiki/ASEAN_Regional_Forum
# /wiki/Asia%E2%80%93Europe_Meeting
# /wiki/SEA_Games
# /wiki/ASEAN_University_Games
# /wiki/ASEAN_School_Games
# /wiki/ASEAN_Para_Games
# /wiki/ASEAN_Football_Federation
# /wiki/ASEAN_Football_Championship
# /wiki/ASEAN_Armies_Rifle_Meet
# /wiki/ASEAN_countries_in_sporting_events
# /wiki/Asian_Monetary_Unit
# /wiki/Chiang_Mai_Initiative
# /wiki/Comprehensive_Economic_Partnership_for_East_Asia
# /wiki/Regional_Comprehensive_Economic_Partnership
# /wiki/ASEAN_Free_Trade_Area
# /wiki/ASEAN%E2%80%93China_Free_Trade_Area
# /wiki/ASEAN%E2%80%93India_Free_Trade_Area
# /wiki/ASEAN%E2%80%93Australia_Development_Cooperation_Program
# /wiki/ASEAN_Centre_for_Biodiversity
# /wiki/The_Asean_Regional_Forum_Disaster_Relief_Exercise
# /wiki/ASEAN_Smart_Cities_Network
# /wiki/ASEAN_Intergovernmental_Commission_on_Human_Rights
# /wiki/ASEAN_Human_Rights_Declaration
# /wiki/ASEAN_Commission_on_the_Promotion_and_Protection_of_the_Rights_of_Women
# /wiki/ASEAN_Common_Time
# /wiki/ASEAN_Rise
# /wiki/ASEAN%E2%80%93European_Union_relations
# /wiki/ASEAN_Outstanding_Scientist_and_Technologist_Award
# /wiki/List_of_ASEAN_countries_by_GDP
# /wiki/List_of_ASEAN_countries_by_HDI
# /wiki/List_of_cities_in_ASEAN_by_population
# /wiki/East_Asia_Summit
# /wiki/First_East_Asia_Summit
# /wiki/Second_East_Asia_Summit
# /wiki/Third_East_Asia_Summit
# /wiki/Fourth_East_Asia_Summit
# /wiki/Fifth_East_Asia_Summit
# /wiki/Sixth_East_Asia_Summit
# /wiki/Seventh_East_Asia_Summit
# /wiki/Eighth_East_Asia_Summit
# /wiki/Ninth_East_Asia_Summit
# /wiki/Tenth_East_Asia_Summit
# /wiki/Eleventh_East_Asia_Summit
# /wiki/Twelfth_East_Asia_Summit
# /wiki/Thirteenth_East_Asia_Summit
# /wiki/Fourteenth_East_Asia_Summit
# /wiki/Fifteenth_East_Asia_Summit
# /wiki/Sixteenth_East_Asia_Summit
# /wiki/Australia
# /wiki/Brunei
# /wiki/Cambodia
# /wiki/China
# /wiki/India
# /wiki/Indonesia
# /wiki/Japan
# /wiki/Laos
# /wiki/Myanmar
# /wiki/New_Zealand
# /wiki/Philippines
# /wiki/Russia
# /wiki/Singapore
# /wiki/South_Korea
# /wiki/Thailand
# /wiki/United_States
# /wiki/Vietnam
# /wiki/Member_states_of_the_Commonwealth_of_Nations
# /wiki/Commonwealth_of_Nations
# /wiki/List_of_sovereign_states
# /wiki/Antigua_and_Barbuda
# /wiki/Australia
# /wiki/The_Bahamas
# /wiki/Bangladesh
# /wiki/Barbados
# /wiki/Belize
# /wiki/Botswana
# /wiki/Brunei
# /wiki/Cameroon
# /wiki/Canada
# /wiki/Cyprus
# /wiki/Dominica
# /wiki/Eswatini
# /wiki/Fiji
# /wiki/The_Gambia
# /wiki/Ghana
# /wiki/Grenada
# /wiki/Guyana
# /wiki/India
# /wiki/Jamaica
# /wiki/Kenya
# /wiki/Kiribati
# /wiki/Lesotho
# /wiki/Malawi
# /wiki/Maldives
# /wiki/Malta
# /wiki/Mauritius
# /wiki/Mozambique
# /wiki/Namibia
# /wiki/Nauru
# /wiki/New_Zealand
# /wiki/Nigeria
# /wiki/Pakistan
# /wiki/Papua_New_Guinea
# /wiki/Rwanda
# /wiki/Saint_Kitts_and_Nevis
# /wiki/Saint_Lucia
# /wiki/Saint_Vincent_and_the_Grenadines
# /wiki/Samoa
# /wiki/Seychelles
# /wiki/Sierra_Leone
# /wiki/Singapore
# /wiki/Solomon_Islands
# /wiki/South_Africa
# /wiki/Sri_Lanka
# /wiki/Tanzania
# /wiki/Tonga
# /wiki/Trinidad_and_Tobago
# /wiki/Tuvalu
# /wiki/Uganda
# /wiki/United_Kingdom
# /wiki/Vanuatu
# /wiki/Zambia
# /wiki/Dependent_territory
# /wiki/Ashmore_and_Cartier_Islands
# /wiki/Australian_Antarctic_Territory
# /wiki/Christmas_Island
# /wiki/Cocos_(Keeling)_Islands
# /wiki/Coral_Sea_Islands
# /wiki/Heard_Island_and_McDonald_Islands
# /wiki/Norfolk_Island
# /wiki/Cook_Islands
# /wiki/Niue
# /wiki/Ross_Dependency
# /wiki/Tokelau
# /wiki/Akrotiri_and_Dhekelia
# /wiki/Anguilla
# /wiki/Bermuda
# /wiki/British_Antarctic_Territory
# /wiki/British_Indian_Ocean_Territory
# /wiki/British_Virgin_Islands
# /wiki/Cayman_Islands
# /wiki/Falkland_Islands
# /wiki/Gibraltar
# /wiki/Bailiwick_of_Guernsey
# /wiki/Isle_of_Man
# /wiki/Jersey
# /wiki/Montserrat
# /wiki/Pitcairn_Islands
# /wiki/Saint_Helena,_Ascension_and_Tristan_da_Cunha
# /wiki/South_Georgia_and_the_South_Sandwich_Islands
# /wiki/Turks_and_Caicos_Islands
# /wiki/Group_of_15
# /wiki/9th_G-15_summit
# /wiki/12th_G-15_summit
# /wiki/13th_G-15_summit
# /wiki/14th_G-15_summit
# /wiki/15th_G-15_summit
# /wiki/Algeria
# /wiki/Argentina
# /wiki/Brazil
# /wiki/Chile
# /wiki/Egypt
# /wiki/India
# /wiki/Indonesia
# /wiki/Iran
# /wiki/Jamaica
# /wiki/Kenya
# /wiki/Mexico
# /wiki/Nigeria
# /wiki/Senegal
# /wiki/Sri_Lanka
# /wiki/Venezuela
# /wiki/Zimbabwe
# /wiki/Asia-Pacific_Economic_Cooperation
# /wiki/Australia
# /wiki/Brunei
# /wiki/Canada
# /wiki/Chile
# /wiki/China
# /wiki/Hong_Kong
# /wiki/Indonesia
# /wiki/Japan
# /wiki/South_Korea
# /wiki/Mexico
# /wiki/New_Zealand
# /wiki/Papua_New_Guinea
# /wiki/Peru
# /wiki/Philippines
# /wiki/Russia
# /wiki/Singapore
# /wiki/Taiwan
# /wiki/Thailand
# /wiki/United_States
# /wiki/Vietnam
# /wiki/APEC_Australia_1989
# /wiki/APEC_Philippines_1996
# /wiki/APEC_Canada_1997
# /wiki/APEC_China_2001
# /wiki/APEC_Mexico_2002
# /wiki/APEC_Thailand_2003
# /wiki/APEC_Chile_2004
# /wiki/APEC_South_Korea_2005
# /wiki/APEC_Vietnam_2006
# /wiki/APEC_Australia_2007
# /wiki/APEC_Peru_2008
# /wiki/APEC_Singapore_2009
# /wiki/APEC_Japan_2010
# /wiki/APEC_United_States_2011
# /wiki/APEC_Russia_2012
# /wiki/APEC_Indonesia_2013
# /wiki/APEC_China_2014
# /wiki/APEC_Philippines_2015
# /wiki/APEC_Peru_2016
# /wiki/APEC_Vietnam_2017
# /wiki/APEC_Papua_New_Guinea_2018
# /wiki/APEC_Chile_2019
# /wiki/APEC_Malaysia_2020
# /wiki/APEC_New_Zealand_2021
# /wiki/APEC_Business_Travel_Card
# /wiki/APEC_blue
# /wiki/APEC_Climate_Center
# /wiki/APEC_Sculpture_Garden
# /wiki/APEC_Youth_Science_Festival
# /wiki/Special_administrative_regions_of_China
# /wiki/Chinese_Taipei
# /wiki/Non-Aligned_Movement
# /wiki/Non-Aligned_Movement#Members,_observers_and_guests
# /wiki/Egypt_and_the_Non-Aligned_Movement
# /wiki/India_and_the_Non-Aligned_Movement
# /wiki/Yugoslavia_and_the_Non-Aligned_Movement
# /wiki/NAM_News_Network
# /wiki/Five_Principles_of_Peaceful_Coexistence
# /wiki/Bandung_Conference
# /wiki/1st_Summit_of_the_Non-Aligned_Movement
# /wiki/2nd_Summit_of_the_Non-Aligned_Movement
# /wiki/3rd_Summit_of_the_Non-Aligned_Movement
# /wiki/5th_Summit_of_the_Non-Aligned_Movement
# /wiki/7th_Summit_of_the_Non-Aligned_Movement
# /wiki/9th_Summit_of_the_Non-Aligned_Movement
# /wiki/16th_Summit_of_the_Non-Aligned_Movement
# /wiki/18th_Summit_of_the_Non-Aligned_Movement
# /wiki/Josip_Broz_Tito#Non-Alignment
# /wiki/Yugoslavia
# /wiki/Sukarno#Figurehead_president
# /wiki/Indonesia
# /wiki/Jawaharlal_Nehru
# /wiki/India
# /wiki/Kwame_Nkrumah
# /wiki/Ghana
# /wiki/Gamal_Abdel_Nasser#Adoption_of_neutralism
# /wiki/Egypt
# /wiki/Houari_Boumediene#Foreign_policy
# /wiki/Nelson_Mandela#Foreign_affairs
# /wiki/Mohamed_Morsi#Non-Aligned_Movement
# /wiki/Nicol%C3%A1s_Maduro
# /wiki/Organisation_of_Islamic_Cooperation
# /wiki/Afghanistan
# /wiki/Albania
# /wiki/Algeria
# /wiki/Azerbaijan
# /wiki/Bahrain
# /wiki/Bangladesh
# /wiki/Benin
# /wiki/Burkina_Faso
# /wiki/Brunei
# /wiki/Cameroon
# /wiki/Chad
# /wiki/Comoros
# /wiki/Djibouti
# /wiki/Egypt
# /wiki/Gabon
# /wiki/The_Gambia
# /wiki/Guinea
# /wiki/Guinea-Bissau
# /wiki/Guyana
# /wiki/Indonesia
# /wiki/Iran
# /wiki/Iraq
# /wiki/Ivory_Coast
# /wiki/Jordan
# /wiki/Kazakhstan
# /wiki/Kuwait
# /wiki/Kyrgyzstan
# /wiki/Lebanon
# /wiki/Libya
# /wiki/Maldives
# /wiki/Mali
# /wiki/Mauritania
# /wiki/Morocco
# /wiki/Mozambique
# /wiki/Niger
# /wiki/Nigeria
# /wiki/Oman
# /wiki/Pakistan
# /wiki/State_of_Palestine
# /wiki/Qatar
# /wiki/Saudi_Arabia
# /wiki/Senegal
# /wiki/Sierra_Leone
# /wiki/Somalia
# /wiki/Sudan
# /wiki/Suriname
# /wiki/Tajikistan
# /wiki/Togo
# /wiki/Tunisia
# /wiki/Turkey
# /wiki/Turkmenistan
# /wiki/Uganda
# /wiki/Uzbekistan
# /wiki/United_Arab_Emirates
# /wiki/Yemen
# /wiki/Syria
# /wiki/Bosnia_and_Herzegovina
# /wiki/Central_African_Republic
# /wiki/Northern_Cyprus
# /wiki/Russia
# /wiki/Thailand
# /wiki/Moro_National_Liberation_Front
# /wiki/Economic_Cooperation_Organization
# /wiki/African_Union
# /wiki/Arab_League
# /wiki/Non-Aligned_Movement
# /wiki/United_Nations
# /wiki/Pacific_Islands_Forum
# /wiki/Australia
# /wiki/Cook_Islands
# /wiki/Fiji
# /wiki/French_Polynesia
# /wiki/Kiribati
# /wiki/Marshall_Islands
# /wiki/Federated_States_of_Micronesia
# /wiki/Nauru
# /wiki/New_Zealand
# /wiki/Niue
# /wiki/Palau
# /wiki/Papua_New_Guinea
# /wiki/New_Caledonia
# /wiki/Samoa
# /wiki/Solomon_Islands
# /wiki/Tonga
# /wiki/Tuvalu
# /wiki/Vanuatu
# /wiki/Tokelau
# /wiki/American_Samoa
# /wiki/East_Timor
# /wiki/Guam
# /wiki/Northern_Mariana_Islands
# /wiki/Wallis_and_Futuna
# /wiki/African,_Caribbean_and_Pacific_Group_of_States
# /wiki/Asian_Development_Bank
# /wiki/Commonwealth_of_Nations
# /wiki/International_Organization_for_Migration
# /wiki/United_Nations
# /wiki/Western_and_Central_Pacific_Fisheries_Commission
# /wiki/World_Bank
# /wiki/Canada
# /wiki/China
# /wiki/Cuba
# /wiki/European_Union
# /wiki/France
# /wiki/Germany
# /wiki/India
# /wiki/Indonesia
# /wiki/Italy
# /wiki/Japan
# /wiki/South_Korea
# /wiki/Philippines
# /wiki/Spain
# /wiki/Thailand
# /wiki/Turkey
# /wiki/United_Kingdom
# /wiki/United_States
# /wiki/45th_Pacific_Islands_Forum
# /wiki/ISNI_(identifier)
# /wiki/VIAF_(identifier)
# /wiki/MBAREA_(identifier)
# /wiki/Geographic_coordinate_system

# %% [markdown]
# ### Saving the results to a CSV file

# %%
import csv 
import requests 

from bs4 import BeautifulSoup

html = requests.get("http://en.wikipedia.org/wiki/Comparison_of_text_editors")
bsObj = BeautifulSoup(html.content, 'html.parser')

#The main comparison table is currently the first table on the page
table = bsObj.findAll("table",{"class":"wikitable"})[0]
rows = table.findAll("tr")

csvFile = open("editors.csv", 'w', encoding='utf8')
writer = csv.writer(csvFile)

try:
    for row in rows:    
        csvRow = []
        for cell in row.findAll(['td', 'th']):
                csvRow.append(cell.get_text())
                writer.writerow(csvRow)
finally:    
    csvFile.close()
