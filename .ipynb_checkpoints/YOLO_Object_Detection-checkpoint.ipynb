# %% [markdown]
# # YOLO v3 Object Detection
#
# Let's see how to use the state of the art in object detection! Please make sure to watch the video, there is no code along here, since we can't reasonably train the YOLOv3 network ourself, instead we will use a pre-established version.
#
# CODE SOURCE: https://github.com/xiaochus/YOLOv3
#
# REFERENCE (for original YOLOv3):
#
#         @article{YOLOv3,
#               title={YOLOv3: An Incremental Improvement},
#               author={J Redmon, A Farhadi },
#               year={2018}
# --------
# ----------
# ## YOU MUST WATCH THE VIDEO LECTURE TO PROPERLY SET UP THE MODEL AND WEIGHTS. THIS NOTEBOOK WON'T WORK UNLESS YOU FOLLOW THE EXACT SET UP SHOWN IN THE VIDEO LECTURE.
# -------
# -------

# %%
import os
import time
import cv2
import numpy as np
from model.yolo_model import YOLO
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 5
#       3 import cv2
#       4 import numpy as np
# ----> 5 from model.yolo_model import YOLO
#
# ModuleNotFoundError: No module named 'model'

# %%
def process_image(img):
    """Resize, reduce and expand image.

    # Argument:
        img: original image.

    # Returns
        image: ndarray(64, 64, 3), processed image.
    """
    image = cv2.resize(img, (416, 416),
                       interpolation=cv2.INTER_CUBIC)
    image = np.array(image, dtype='float32')
    image /= 255.
    image = np.expand_dims(image, axis=0)

    return image

# %%
def get_classes(file):
    """Get classes name.

    # Argument:
        file: classes name for database.

    # Returns
        class_names: List, classes name.

    """
    with open(file) as f:
        class_names = f.readlines()
    class_names = [c.strip() for c in class_names]

    return class_names

# %%
def draw(image, boxes, scores, classes, all_classes):
    """Draw the boxes on the image.

    # Argument:
        image: original image.
        boxes: ndarray, boxes of objects.
        classes: ndarray, classes of objects.
        scores: ndarray, scores of objects.
        all_classes: all classes name.
    """
    for box, score, cl in zip(boxes, scores, classes):
        x, y, w, h = box

        top = max(0, np.floor(x + 0.5).astype(int))
        left = max(0, np.floor(y + 0.5).astype(int))
        right = min(image.shape[1], np.floor(x + w + 0.5).astype(int))
        bottom = min(image.shape[0], np.floor(y + h + 0.5).astype(int))

        cv2.rectangle(image, (top, left), (right, bottom), (255, 0, 0), 2)
        cv2.putText(image, '{0} {1:.2f}'.format(all_classes[cl], score),
                    (top, left - 6),
                    cv2.FONT_HERSHEY_SIMPLEX,
                    0.6, (0, 0, 255), 1,
                    cv2.LINE_AA)

        print('class: {0}, score: {1:.2f}'.format(all_classes[cl], score))
        print('box coordinate x,y,w,h: {0}'.format(box))

    print()

# %%
def detect_image(image, yolo, all_classes):
    """Use yolo v3 to detect images.

    # Argument:
        image: original image.
        yolo: YOLO, yolo model.
        all_classes: all classes name.

    # Returns:
        image: processed image.
    """
    pimage = process_image(image)

    start = time.time()
    boxes, classes, scores = yolo.predict(pimage, image.shape)
    end = time.time()

    print('time: {0:.2f}s'.format(end - start))

    if boxes is not None:
        draw(image, boxes, scores, classes, all_classes)

    return image

# %%
def detect_video(video, yolo, all_classes):
    """Use yolo v3 to detect video.

    # Argument:
        video: video file.
        yolo: YOLO, yolo model.
        all_classes: all classes name.
    """
    video_path = os.path.join("videos", "test", video)
    camera = cv2.VideoCapture(video_path)
    cv2.namedWindow("detection", cv2.WINDOW_AUTOSIZE)

    # Prepare for saving the detected video
    sz = (int(camera.get(cv2.CAP_PROP_FRAME_WIDTH)),
        int(camera.get(cv2.CAP_PROP_FRAME_HEIGHT)))
    fourcc = cv2.VideoWriter_fourcc(*'mpeg')

    
    vout = cv2.VideoWriter()
    vout.open(os.path.join("videos", "res", video), fourcc, 20, sz, True)

    while True:
        res, frame = camera.read()

        if not res:
            break

        image = detect_image(frame, yolo, all_classes)
        cv2.imshow("detection", image)

        # Save the video frame by frame
        vout.write(image)

        if cv2.waitKey(110) & 0xff == 27:
                break

    vout.release()
    camera.release()

# %%
yolo = YOLO(0.6, 0.5)
file = 'data/coco_classes.txt'
all_classes = get_classes(file)
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %% [markdown]
# ### Detecting Images

# %%
f = 'jingxiang-gao-489454-unsplash.jpg'
path = 'images/test/'+f
image = cv2.imread(path)
image = detect_image(image, yolo, all_classes)
cv2.imwrite('images/res/' + f, image)
# Out:
# time: 3.80s
# class: person, score: 0.64
# box coordinate x,y,w,h: [2523.8918066  1482.56186676  619.4088757  1302.60207367]
# class: bicycle, score: 0.84
# box coordinate x,y,w,h: [2877.69520283 2008.98068333 1303.69895697  717.74808955]
# True

# %% [markdown]
# # Detecting on Video

# %%
# # detect videos one at a time in videos/test folder    
video = 'library1.mp4'
detect_video(video, yolo, all_classes)
# Out:
# time: 0.93s
# class: person, score: 1.00
# box coordinate x,y,w,h: [422.23278522 476.16264343 173.45145106 374.28127289]
# class: bicycle, score: 0.99
# box coordinate x,y,w,h: [369.0729475  635.68229675 295.86342573 255.98890305]
#
# time: 0.97s
# class: person, score: 1.00
# box coordinate x,y,w,h: [401.12045288 476.81560516 175.63254833 369.44404602]
# class: bicycle, score: 0.99
# box coordinate x,y,w,h: [333.17786694 629.88777161 318.9031291  263.77016068]
#
# time: 1.00s
# class: person, score: 1.00
# box coordinate x,y,w,h: [387.98526764 483.2711792  185.45417547 369.34688568]
# class: bicycle, score: 0.99
# box coordinate x,y,w,h: [319.77162838 671.82174683 346.40808821 246.46858215]
#
# time: 0.90s
# class: person, score: 1.00
# box coordinate x,y,w,h: [387.6414299  482.35267639 184.81741905 358.74912262]
# class: bicycle, score: 0.99
# box coordinate x,y,w,h: [320.55618525 649.58030701 330.62783718 247.75081635]
#
# time: 0.97s
# class: person, score: 1.00
# box coordinate x,y,w,h: [380.89543819 481.66233063 191.67005539 367.69493103]
# class: bicycle, score: 0.99
# box coordinate x,y,w,h: [309.51977491 675.86006165 346.8478632  242.96504974]
#
# time: 1.00s
# class: person, score: 1.00
# box coordinate x,y,w,h: [379.00514603 473.30821991 190.52846432 383.92250061]
# class: bicycle, score: 1.00
# box coordinate x,y,w,h: [307.20425606 666.54602051 354.51241493 260.42503357]
#
# time: 0.99s
# class: person, score: 1.00
# box coordinate x,y,w,h: [374.89548683 472.15560913 198.64772558 394.308815  ]
# class: bicycle, score: 0.99
# box coordinate x,y,w,h: [296.85614347 668.61877441 377.72708416 262.31351852]
#
# time: 1.02s
# class: person, score: 1.00
# box coordinate x,y,w,h: [380.87818623 464.28733826 196.19015694 420.35263062]
# class: bicycle, score: 0.99
# box coordinate x,y,w,h: [296.01809263 663.31497192 386.01189137 279.13917542]
#
# time: 0.91s
# class: person, score: 1.00
# box coordinate x,y,w,h: [386.71089649 455.44750214 193.6460495  441.90834045]
# class: bicycle, score: 0.99
# box coordinate x,y,w,h: [292.92629957 661.69242859 392.66033649 280.9176445 ]
#
# time: 0.91s
# class: person, score: 1.00
# box coordinate x,y,w,h: [390.13360977 472.00378418 180.80794573 413.7027359 ]
# class: bicycle, score: 0.99
# box coordinate x,y,w,h: [291.11591578 663.41110229 397.87849903 279.20291901]
#
# time: 0.91s
# class: person, score: 1.00
# box coordinate x,y,w,h: [391.7975235  471.66358948 180.27581692 423.15692902]
# class: person, score: 0.67
# box coordinate x,y,w,h: [359.9535656  596.27754211 292.83688545 307.76721954]
# class: bicycle, score: 0.99
# box coordinate x,y,w,h: [286.42797232 658.40087891 414.30305958 288.26442719]
#
# time: 0.93s
# class: person, score: 0.98
# box coordinate x,y,w,h: [414.61621284 473.81996155 193.32261801 411.58401489]
# class: bicycle, score: 0.99
# box coordinate x,y,w,h: [293.87569427 657.04948425 400.58203697 296.33556366]
#
# time: 0.98s
# class: person, score: 0.99
# box coordinate x,y,w,h: [413.53989601 467.84893036 199.61864233 420.47660828]
# class: bicycle, score: 0.99
# box coordinate x,y,w,h: [268.34823132 683.67599487 475.67170143 270.28614044]
#
# time: 0.98s
# class: person, score: 0.99
# box coordinate x,y,w,h: [419.27321434 467.10414886 191.67061329 425.72029114]
# class: bicycle, score: 0.99
# box coordinate x,y,w,h: [266.40111923 676.74514771 483.48787308 284.49104309]
#
# time: 0.95s
# class: person, score: 0.97
# box coordinate x,y,w,h: [423.15216064 477.66212463 186.36024714 403.96713257]
# class: bicycle, score: 0.99
# box coordinate x,y,w,h: [281.4942956  677.88719177 461.41363621 290.42375565]
#
# time: 1.04s
# class: person, score: 0.96
# box coordinate x,y,w,h: [413.45694065 441.77078247 211.76377058 480.16662598]
# class: bicycle, score: 0.99
# box coordinate x,y,w,h: [270.20391226 677.81303406 484.08546925 291.00261688]
#
# time: 1.03s
# class: person, score: 0.94
# box coordinate x,y,w,h: [369.02415276 509.54864502 292.15575457 430.77655792]
# class: bicycle, score: 0.99
# box coordinate x,y,w,h: [278.705163   640.93269348 461.92445755 349.37343597]
#
# time: 0.98s
# class: person, score: 0.91
# box coordinate x,y,w,h: [363.99936676 509.34585571 296.09832287 431.01032257]
# class: bicycle, score: 0.99
# box coordinate x,y,w,h: [278.91967535 643.06800842 459.12324429 350.75454712]
#
# time: 0.97s
# class: person, score: 0.95
# box coordinate x,y,w,h: [339.11670685 506.22810364 299.88673925 449.60952759]
# class: bicycle, score: 0.99
# box coordinate x,y,w,h: [276.06831551 640.82878113 459.25435066 349.59522247]
#
# time: 0.99s
# class: person, score: 0.96
# box coordinate x,y,w,h: [334.85937595 511.61678314 293.35553885 445.66139221]
# class: bicycle, score: 0.99
# box coordinate x,y,w,h: [283.75069857 625.12447357 410.2846384  361.19621277]
#
# time: 0.94s
# class: person, score: 0.99
# box coordinate x,y,w,h: [372.05393314 434.1411972  215.63306093 494.89601135]
# class: bicycle, score: 0.99
# box coordinate x,y,w,h: [263.96279812 623.66016388 432.02130318 366.96662903]
#
# time: 1.01s
# class: person, score: 0.99
# box coordinate x,y,w,h: [359.58316326 447.1710968  230.56586266 464.16103363]
# class: bicycle, score: 0.99
# box coordinate x,y,w,h: [215.98861456 676.62757874 493.8107729  288.11483383]
#
# time: 0.94s
# class: person, score: 0.98
# box coordinate x,y,w,h: [343.24366093 463.98983002 244.61677551 437.6474762 ]
# class: bicycle, score: 0.99
# box coordinate x,y,w,h: [216.19628191 645.14907837 479.75986004 347.37586975]
#
# time: 0.95s
# class: person, score: 0.98
# box coordinate x,y,w,h: [336.30779028 454.09420013 237.27151394 453.46656799]
# class: bicycle, score: 0.99
# box coordinate x,y,w,h: [213.24709654 633.4633255  438.34372044 351.09062195]
#
# time: 0.91s
# class: person, score: 0.99
# box coordinate x,y,w,h: [319.2604208  469.87792969 208.44800234 413.61797333]
# class: bicycle, score: 0.99
# box coordinate x,y,w,h: [172.4781847  676.75544739 489.86474991 294.67897415]
#
# time: 0.92s
# class: person, score: 1.00
# box coordinate x,y,w,h: [297.03705311 472.00706482 222.24389076 403.80146027]
# class: bicycle, score: 0.98
# box coordinate x,y,w,h: [141.15803003 689.48783875 517.75152683 276.97214127]
#
# time: 0.92s
# class: person, score: 1.00
# box coordinate x,y,w,h: [268.65685701 464.16408539 211.99635029 408.17558289]
# class: bicycle, score: 0.99
# box coordinate x,y,w,h: [163.00923586 632.69241333 423.84974957 355.11165619]
#
# time: 0.90s
# class: person, score: 1.00
# box coordinate x,y,w,h: [259.06405449 471.10740662 219.22395945 400.99460602]
# class: bicycle, score: 0.99
# box coordinate x,y,w,h: [114.4217062  685.34332275 467.38796711 279.53681946]
#
# time: 0.90s
# class: person, score: 1.00
# box coordinate x,y,w,h: [247.6823473  470.34866333 209.02358294 404.48932648]
# class: bicycle, score: 0.99
# box coordinate x,y,w,h: [115.8915782  676.19056702 421.16938591 284.81607437]
#
# time: 0.91s
# class: person, score: 0.99
# box coordinate x,y,w,h: [235.3221488  474.73327637 213.30432415 404.54647064]
# class: bicycle, score: 1.00
# box coordinate x,y,w,h: [101.46101475 677.98141479 433.43167305 280.87806702]
#
# time: 0.90s
# class: person, score: 1.00
# box coordinate x,y,w,h: [214.17838097 478.4803009  208.10450792 389.44568634]
# class: bicycle, score: 1.00
# box coordinate x,y,w,h: [ 74.08435106 682.60894775 439.00320053 276.29756927]
#
# time: 0.88s
# class: person, score: 1.00
# box coordinate x,y,w,h: [202.81220913 479.21413422 198.25582266 372.29347229]
# class: bicycle, score: 0.99
# box coordinate x,y,w,h: [ 51.49143934 685.56335449 462.4848032  265.31435013]
#
# time: 0.91s
# class: person, score: 1.00
# box coordinate x,y,w,h: [190.47001362 487.22774506 201.84174299 346.54075623]
# class: bicycle, score: 0.99
# box coordinate x,y,w,h: [ 55.57013512 678.44924927 415.85234642 272.59433746]
#
# time: 0.96s
# class: person, score: 0.99
# box coordinate x,y,w,h: [163.6231184  485.75057983 197.71532536 353.93981934]
# class: bicycle, score: 0.99
# box coordinate x,y,w,h: [ 56.5552783  682.19047546 383.34920883 262.22978592]
#
# time: 0.95s
# class: person, score: 1.00
# box coordinate x,y,w,h: [149.5109117  491.99523926 207.2642684  349.21344757]
# class: bicycle, score: 1.00
# box coordinate x,y,w,h: [ 28.12180281 685.26611328 401.33773327 255.34433365]
#
# time: 0.89s
# class: person, score: 1.00
# box coordinate x,y,w,h: [141.72902942 493.5043335  204.16822672 341.5832901 ]
# class: bicycle, score: 1.00
# box coordinate x,y,w,h: [ 28.75411749 681.71913147 372.47291565 261.94673538]
#
# time: 0.92s
# class: person, score: 0.99
# box coordinate x,y,w,h: [115.59737206 504.60845947 189.30550575 320.02212524]
# class: bicycle, score: 0.99
# box coordinate x,y,w,h: [ 19.47177529 674.86999512 355.25654554 257.07550049]
# time: 0.89s
# class: person, score: 1.00
# box coordinate x,y,w,h: [102.07807302 496.13487244 196.69977665 345.53043365]
# class: bicycle, score: 0.99
# box coordinate x,y,w,h: [ 11.51026011 673.45565796 337.63299465 257.35544205]
#
# time: 0.94s
# class: person, score: 1.00
# box coordinate x,y,w,h: [ 89.69545126 493.44749451 199.58660603 345.91110229]
# class: bicycle, score: 0.99
# box coordinate x,y,w,h: [  3.77275229 681.42959595 317.88180828 247.25728989]
#
# time: 0.99s
# class: person, score: 0.99
# box coordinate x,y,w,h: [ 63.77949715 504.38163757 181.92932367 316.12703323]
# class: bicycle, score: 0.99
# box coordinate x,y,w,h: [-14.15313721 681.24809265 331.01673603 234.24030304]
#
# time: 0.95s
# class: person, score: 1.00
# box coordinate x,y,w,h: [ 54.52458322 501.09573364 177.74517417 321.39957428]
# class: bicycle, score: 0.99
# box coordinate x,y,w,h: [-15.28892398 683.48716736 303.9885664  225.73596954]
#
# time: 0.94s
# class: person, score: 1.00
# box coordinate x,y,w,h: [ 37.83242941 491.90101624 190.91839314 341.36203766]
# class: bicycle, score: 0.99
# box coordinate x,y,w,h: [-14.5228529  685.77552795 279.73860741 219.52075958]
#
# time: 0.96s
# class: person, score: 1.00
# box coordinate x,y,w,h: [ 23.04470301 493.22975159 196.47296906 346.43161774]
# class: bicycle, score: 0.95
# box coordinate x,y,w,h: [-16.61300182 684.46578979 268.29231262 220.70625305]
#
# time: 1.00s
# class: person, score: 1.00
# box coordinate x,y,w,h: [  6.08105063 482.01087952 176.99461699 350.30994415]
# class: bicycle, score: 0.97
# box coordinate x,y,w,h: [-12.98855424 644.36271667 232.80095816 242.3768425 ]
#
# time: 0.94s
# class: person, score: 1.00
# box coordinate x,y,w,h: [  4.80807424 484.00302887 166.60894275 341.84455872]
# class: bicycle, score: 0.96
# box coordinate x,y,w,h: [ -9.87312555 649.52072144 209.35639143 229.90566254]
#
# time: 0.97s
# class: person, score: 0.99
# box coordinate x,y,w,h: [  2.7889663  492.70030975 160.64707875 312.94118881]
# class: bicycle, score: 0.81
# box coordinate x,y,w,h: [ -4.19682562 642.97019958 182.30440378 224.78563309]
#
# time: 0.89s
# class: person, score: 0.99
# box coordinate x,y,w,h: [3.96296382e-01 4.75018654e+02 1.52915332e+02 3.44840012e+02]
# class: bicycle, score: 0.69
# box coordinate x,y,w,h: [ -0.87206125 637.13569641 157.6471138  215.08314133]
#
# time: 0.97s
# class: person, score: 0.89
# box coordinate x,y,w,h: [ 10.72453916 496.19560242 106.38003588 323.20957184]
# class: bicycle, score: 0.91
# box coordinate x,y,w,h: [  9.37292039 609.14310455 120.99125147 288.64553452]
#
# time: 0.95s
# class: person, score: 0.77
# box coordinate x,y,w,h: [ -4.19837326 437.1647644   88.62599015 379.55524445]
# class: bicycle, score: 0.85
# box coordinate x,y,w,h: [  7.34633982 580.10452271 107.8774488  287.5369072 ]
#
# time: 0.91s
# class: person, score: 0.73
# box coordinate x,y,w,h: [ -6.19090319 427.04399109  84.37851369 399.15016174]
# class: bicycle, score: 0.85
# box coordinate x,y,w,h: [ -9.69696879 577.17647552 101.89239979 287.24769592]
#
# time: 0.93s
# class: bicycle, score: 0.83
# box coordinate x,y,w,h: [-12.48557568 574.0120697   95.54106832 279.8077774 ]
#
# time: 1.01s
# class: bicycle, score: 0.67
# box coordinate x,y,w,h: [-10.83676279 582.99919128  89.97735143 269.96456146]
#
# time: 0.98s
# time: 1.00s
# time: 0.99s
# time: 0.94s
# class: motorbike, score: 0.66
# box coordinate x,y,w,h: [593.47977161 737.98408508 126.61373019 170.76795578]
#
# time: 0.95s
# class: motorbike, score: 0.73
# box coordinate x,y,w,h: [573.68652821 738.16963196 147.48511434 169.17413712]
#
# time: 0.94s
# class: motorbike, score: 0.81
# box coordinate x,y,w,h: [533.20478439 724.53201294 187.84421682 185.82115173]
#
# time: 0.99s
# class: motorbike, score: 0.85
# box coordinate x,y,w,h: [503.90201569 706.31088257 193.1006813  210.86830139]
#
# time: 1.03s
# class: motorbike, score: 0.81
# box coordinate x,y,w,h: [481.12242222 701.65527344 223.32947731 209.86087799]
#
# time: 1.00s
# time: 0.98s
# time: 1.00s
# time: 0.95s
# time: 1.16s
# time: 1.29s
# time: 1.44s
# class: motorbike, score: 0.68
# box coordinate x,y,w,h: [327.46257305 660.6804657  271.5935111  219.24591064]
#
# time: 1.16s
# class: motorbike, score: 0.67
# box coordinate x,y,w,h: [292.11350441 695.04394531 282.43987083 203.15925598]
#
# time: 1.11s
# class: motorbike, score: 0.78
# box coordinate x,y,w,h: [278.60570669 653.62724304 290.48508167 232.98173904]
