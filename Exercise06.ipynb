# %% [markdown]
# <img src="https://i.imgur.com/FoKB5Z5.png" align="left" width="300" height="250" title="source: imgur.com" /></a>

# %% [markdown]
# ## Program Code: J620-002-4:2020
#
# ## Program Name: FRONT-END SOFTWARE DEVELOPMENT
#
# ## Title : Exercise 6 - Pandas
#
# #### Name: Chuay Xiang Ze
#
# #### IC Number: 021224070255
#
# #### Date : 22/06/2023
#
# #### Introduction : Learning how to use pandas functions
#
#
#
# #### Conclusion : Learnt the likes of how to read files and also using head, value_counts and many more.

# %% [markdown]
# EXERCISE 6
# ==
# ## Pandas

# %%
import pandas as pd

# %% [markdown]
# ## Question 1
#
# UFO (Unidentified Flying Objects) data is from http://www.nuforc.org/webreports.html.
#
# Given the UFO sightings data and the path for csv file, read the csv file from the URL.

# %%
path ='http://bit.ly/uforeports'

# %% [markdown]
# use the read_csv to read the csv and assign to a variable called 'ufo'

# %%
#read csv
ufo = pd.read_csv(path)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

ufo
# Out:
#      star_rating                                              title  \
# 0            9.3                           The Shawshank Redemption
# 1            9.2                                      The Godfather
# 2            9.1                             The Godfather: Part II
# 3            9.0                                    The Dark Knight
# 4            8.9                                       Pulp Fiction
# 5            8.9                                       12 Angry Men
# 6            8.9                     The Good, the Bad and the Ugly
# 7            8.9      The Lord of the Rings: The Return of the King
# 8            8.9                                   Schindler's List
# 9            8.9                                         Fight Club
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 11           8.8                                          Inception
# 12           8.8     Star Wars: Episode V - The Empire Strikes Back
# ...

# %%
#show the top 5 rows of data
ufo.head(5)
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
#show the last 10 rows of data
ufo.tail(10)
# Out:
#                  City Colors Reported Shape Reported State              Time
# 18231     Pismo Beach             NaN           OVAL    CA  12/31/2000 20:00
# 18232            Lodi             NaN            NaN    WI  12/31/2000 20:30
# 18233       Anchorage             RED        VARIOUS    AK  12/31/2000 21:00
# 18234        Capitola             NaN       TRIANGLE    CA  12/31/2000 22:00
# 18235  Fountain Hills             NaN            NaN    AZ  12/31/2000 23:00
# 18236      Grant Park             NaN       TRIANGLE    IL  12/31/2000 23:00
# 18237     Spirit Lake             NaN           DISK    IA  12/31/2000 23:00
# 18238     Eagle River             NaN            NaN    WI  12/31/2000 23:45
# 18239     Eagle River             RED          LIGHT    WI  12/31/2000 23:45
# 18240            Ybor             NaN           OVAL    FL  12/31/2000 23:59

# %%
#check the data type
type(ufo)
# Out:
# pandas.core.frame.DataFrame

# %%
#check the data type for 'Time' column
ufo['Time'].dtype
# Out:
# dtype('O')

# %%
#show all rows for the column 'City'
len(ufo['City'].unique())
# Out:
# 6477

# %%
#determine the shape of the data
ufo.shape
# Out:
# (18241, 5)

# %%
#show all data for 'City' that starts with 'E'
ufo[ufo['City'].str.startswith('E', na=False)][['City']]
# Out:
#                  City
# 8             Eklutna
# 55           Espanola
# 109         Excelsior
# 140    East Palestine
# 179         Evergreen
# ...               ...
# 18182      Evansville
# 18215        El Campo
# 18224         Eufaula
# 18238     Eagle River
# 18239     Eagle River
#
# [557 rows x 1 columns]

# %%
# count number of reported cases for 'CIRCLE'
# and count the number of reported cases for 'LIGHT'
circle = len(ufo[ufo['Shape Reported'] == 'CIRCLE'])
print(circle)

light = len(ufo[ufo['Shape Reported'] == 'LIGHT'])
print(light)
# Out:
# 1365
# 2803

# %%
#determine what are the top three colors reported

ufo['Colors Reported'].value_counts().nlargest(3)
# Out:
# RED       780
# GREEN     531
# ORANGE    528
# Name: Colors Reported, dtype: int64

# %%
#count the number of shape reported by state and city

# subset = ufo[['Shape Reported', 'State', 'City']]

# subset.head()

ufo.groupby(['State', 'City'])['Shape Reported'].size()
# Out:
# State  City
# AK     Adak                          1
#        Alaska                        2
#        Anchorage                    12
#        Arctic                        1
#        Auke Bay                      2
#                                     ..
# WY     Ten Sleep                     1
#        Wheeling                      1
#        Wyoming                       2
#        Yellowstone National Park     1
#        Yellowstone Park              1
# Name: Shape Reported, Length: 8029, dtype: int64

# %% [markdown]
# ## Question 2
#
# IMDB ratings are from http://www.imdb.com/search/title?groups=top_1000&sort=user_rating&view=simple
#
# Given the IMDB movies dataset and path, use the read_csv to read the data and assign to a variable 'movies'

# %%
path = 'http://bit.ly/imdbratings'

# %%
#read the dataset

movies = pd.read_csv(path)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

movies
# Out:
#      star_rating                                              title  \
# 0            9.3                           The Shawshank Redemption
# 1            9.2                                      The Godfather
# 2            9.1                             The Godfather: Part II
# 3            9.0                                    The Dark Knight
# 4            8.9                                       Pulp Fiction
# 5            8.9                                       12 Angry Men
# 6            8.9                     The Good, the Bad and the Ugly
# 7            8.9      The Lord of the Rings: The Return of the King
# 8            8.9                                   Schindler's List
# 9            8.9                                         Fight Club
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 11           8.8                                          Inception
# 12           8.8     Star Wars: Episode V - The Empire Strikes Back
# ...

# %%
#show the top 10 rows
movies.head(10)
# Out:
#    star_rating                                          title content_rating  \
# 0          9.3                       The Shawshank Redemption              R
# 1          9.2                                  The Godfather              R
# 2          9.1                         The Godfather: Part II              R
# 3          9.0                                The Dark Knight          PG-13
# 4          8.9                                   Pulp Fiction              R
# 5          8.9                                   12 Angry Men      NOT RATED
# 6          8.9                 The Good, the Bad and the Ugly      NOT RATED
# 7          8.9  The Lord of the Rings: The Return of the King          PG-13
# 8          8.9                               Schindler's List              R
# 9          8.9                                     Fight Club              R
#
#        genre  duration                                        actors_list
# ...

# %%
#show summary of the dataset
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 979 entries, 0 to 978
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   star_rating     979 non-null    float64
#  1   title           979 non-null    object
#  2   content_rating  976 non-null    object
#  3   genre           979 non-null    object
#  4   duration        979 non-null    int64
#  5   actors_list     979 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 46.0+ KB

# %%
#determine the dimension of the dataset
movies.shape
# Out:
# (979, 6)

# %%
#show the data types for each coloumns
movies.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %%
#show all the column names
movies.columns
# Out:
# Index(['star_rating', 'title', 'content_rating', 'genre', 'duration',
#        'actors_list'],
#       dtype='object')

# %%
# rename the following columns, 'star_rating' as 'stars_rating'
# 'content_rating' as 'content' 

movies.rename(columns={
        'star_rating': 'stars_rating',
        'content_rating': 'content'
    }, inplace=True)


movies.columns
# Out:
# Index(['stars_rating', 'title', 'content', 'genre', 'duration', 'actors_list'], dtype='object')

# %%
#given a list called 'col_names' change all the columns names to 'col_names'
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[98], line 2
#       1 #given a list called 'col_names' change all the columns names to 'col_names'
# ----> 2 movies.columns = [col.rename('col_names') for col in movies]
#       4 movies.columns
#
# Cell In[98], line 2, in <listcomp>(.0)
#       1 #given a list called 'col_names' change all the columns names to 'col_names'
# ----> 2 movies.columns = [col.rename('col_names') for col in movies]
#       4 movies.columns
#
# AttributeError: 'str' object has no attribute 'rename'

# %%
#provide the statistical summary for 'star_rating' and 'duration'
movies.describe()
# Out:
#        stars_rating    duration
# count    979.000000  979.000000
# mean       7.889785  120.979571
# std        0.336069   26.218010
# min        7.400000   64.000000
# 25%        7.600000  102.000000
# 50%        7.800000  117.000000
# 75%        8.100000  134.000000
# max        9.300000  242.000000

# %%
#show the data type for column 'star_rating'
movies['stars_rating'].dtype
# Out:
# dtype('float64')

# %%
#show the 5th row data for column 'content_rating'
movies['content'][4]
# Out:
# 'R'

# %%
#show all rows for movies duration more than 200 mins
movies[movies['duration'] > 200]
# Out:
#      stars_rating                                          title  \
# 7             8.9  The Lord of the Rings: The Return of the King
# 17            8.7                                  Seven Samurai
# 78            8.4                    Once Upon a Time in America
# 85            8.4                             Lawrence of Arabia
# 142           8.3              Lagaan: Once Upon a Time in India
# 157           8.2                             Gone with the Wind
# 204           8.1                                        Ben-Hur
# 445           7.9                           The Ten Commandments
# 476           7.8                                         Hamlet
# 630           7.7                                      Malcolm X
# 767           7.6                It's a Mad, Mad, Mad, Mad World
#
#     content_rating      genre  duration  \
# 7            PG-13  Adventure       201
# 17         UNRATED      Drama       207
# 78               R      Crime       229
# ...

# %%
#what is the average movie duration
sum = 0
for i in movies['duration']:
    sum += i
    
print(sum / len(movies['duration']))
print(movies['duration'].mean())
# Out:
# 120.97957099080695
# 120.97957099080695

# %%
#count the number of movies where actor 'Charlton Heston' acted in
len(movies[movies['actors_list'].str.contains('Charlton Heston')])
# Out:
# 4

# %%
#what are the top 5 genre movies
genre_counts = movies['genre'].value_counts()

plt.bar(genre_counts.index, genre_counts.values)
plt.title('Frequency of Movie Genres')
plt.xticks(rotation=45)
plt.show()

# %%
#which movie has the highest rating
temp_movies = movies.sort_values('stars_rating', ascending=False)
highest = temp_movies['title']
highest.head(1)
# Out:
# 0    The Shawshank Redemption
# Name: title, dtype: object

# %%
#which movie has the lowest rating
lowest_rating = movies[movies['stars_rating'] == movies['stars_rating'].min()]
lowest_rating
# Out:
#      stars_rating                                            title  \
# 930           7.4                                  Man on the Moon
# 931           7.4                                     Mean Streets
# 932           7.4        Harry Potter and the Order of the Phoenix
# 933           7.4                                      Beetlejuice
# 934           7.4                             Crazy, Stupid, Love.
# 935           7.4                                        Excalibur
# 936           7.4                                        True Grit
# 937           7.4                                        Labyrinth
# 938           7.4                              Alice in Wonderland
# 939           7.4                                   Predestination
# 940           7.4                           Much Ado About Nothing
# 941           7.4                                 A Bridge Too Far
# 942           7.4                                  Raising Arizona
# ...

# %%
# group by genre and content rating and calculate the mean for duration

movies.groupby(['genre', 'content_rating'])['duration'].mean()
# Out:
# genre      content_rating
# Action     APPROVED          143.333333
#            G                 178.000000
#            GP                144.000000
#            NOT RATED         129.500000
#            PASSED             98.000000
#            PG                119.727273
#            PG-13             130.204545
#            R                 123.850746
#            UNRATED           110.666667
# Adventure  APPROVED          158.333333
#            G                 162.000000
#            NOT RATED         113.200000
#            PASSED            102.000000
#            PG                133.952381
#            PG-13             143.913043
#            R                 124.882353
#            UNRATED           136.000000
# Animation  APPROVED           84.666667
#            G                  93.150000
#            NOT RATED          91.000000
#            PG                 99.360000
#            PG-13             104.200000
#            R                 101.000000
# ...
